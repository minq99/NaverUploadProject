# %% [markdown]
# ### OAuth2
# - 인증을 위한 개방형 표준 프로토콜
# - OAuth2의 주요 목표는 사용자의 아이디와 비밀번호를 공유하지 않고도, 제 3자 애플리케이션에 사용자를 대신해 특정 작업을 수행하도록 허용하는 것
# - Client Credentials Grant 방식: 클라이언트가 자신의 인증 정보(id/pw)를 보내서 액세스 Token을 발급받는 방식.

# %%
# 네이버커머스 Auth 정책
# 커머스API는 인증 토큰 발급 요청 시 직접 클라이언트 시크릿 값을 전달하지 않고 전자서명(signature)을 생성 후 전달
# 동일 리소스(type과 account_id에 따라)에는 하나의 인증 토큰의 발급되며 인증 토큰의 유효 시간은 3시간(10,800초)
# 발급된 인증 토큰이 존재하는 경우 남은 유효 시간이 30분 이상이면 기존 인증 토큰이 반환되고 30분 미만이면 새로운 인증 토큰이 발급됩니다
# 새로운 인증 토큰이 발급된 경우에도 유효 시간이 만료되기 전까지는 기존 인증 토큰을 사용할 수 있습니다.

# %%
import bcrypt
import pybase64
import requests
import json
import http.client
import pandas as pd
import time
import datetime
import os
import base64
from itertools import product
import tools.Common
from tools.UploadTool import * 
from tools.SearchTool import *
from tools.RenewTool import *
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10568\3690910837.py:6: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # 내 채널 상품 조회

# %%
# 스마트스토어센터에서는 "채널상품번호"만을 제공함. -> 채널 상품 번호로 조회해야함 
search_product(9771082183)
# Out:
# '{"originProduct":{"statusType":"SALE","saleType":"NEW","leafCategoryId":"50000836","name":"[Olekei] 사루엘 남성 바지 와이드 팬츠 9부 무지 조정끈 인기 쾌적 넉넉한 통기성 큰 사이즈 캐주얼 하카마 팬츠 편안함 사계절 봄 여름 가을 겨울","detailContent":"<div class=\\"se-viewer se-theme-default\\" lang=\\"ko-KR\\">\\n    <!-- SE_DOC_HEADER_START -->\\n    <!--@CONTENTS_HEADER-->\\n    <!-- SE_DOC_HEADER_END -->\\n    <div class=\\"se-main-container\\">\\n                <div class=\\"se-component se-text se-l-default\\" id=\\"SE-d8431b9e-3e1b-481d-b281-a7a349c2f597\\">\\n                    <div class=\\"se-component-content\\">\\n                        <div class=\\"se-section se-section-text se-l-default\\">\\n                            <div class=\\"se-module se-module-text\\">\\n                                    <!-- SE-TEXT { --><p class=\\"se-text-paragraph se-text-paragraph-align- \\" style=\\"\\" id=\\"SE-25931c06-b52a-435b-afde-55de381d8d9f\\"><span style=\\"color:#000000;background-color:#fdfdfd;\\" class=\\"se-fs-fs24 se-ff-system  se-style-unset \\" id=\\"SE-6a3544df-f19a-46e4-9c6b-26898d511159\\">사이즈</span></p><p class=\\"se-text-paragraph se-text-paragraph-align- \\" style=\\"\\" id=\\"SE-8b2f5eed-eea8-4b09-bd45-eec91c603e46\\"><span style=\\"color:#000000;background-color:#fdfdfd;\\" class=\\"se-fs-fs24 se-ff-system  se-style-unset \\" id=\\"SE-59c8f34c-c70f-443f-9185-5ef93526dbfa\\">허리/엉덩이/총기장 </span></p><p class=\\"se-text-paragraph se-text-paragraph-align- \\" style=\\"\\" id=\\"SE-c495ce20-e5a8-4c2a-8862-a1310470912e\\"><span style=\\"color:#000000;background-color:#fdfdfd;\\" class=\\"se-fs-fs24 se-ff-system  se-style-unset \\" id=\\"SE-fde1c657-be7a-41c3-bbfa-854c66d3e3b5\\">M     68/108</span></p><p class=\\"se-text-paragraph se-text-paragraph-align- \\" style=\\"\\" id=\\"SE-25875601-b7d3-48c7-951e-10f2522ce0a1\\"><span style=\\"color:#000000;background-color:#fdfdfd;\\" class=\\"se-fs-fs24 se-ff-system  se-style-unset \\" id=\\"SE-a1d8cd24-0041-4643-83f4-eafb1518dbd8\\">L      72/112/101 </span></p><p class=\\"se-text-paragraph se-text-paragraph-align- \\" style=\\"\\" id=\\"SE-e0c51604-61ba-452d-9ac7-9d46e80ee1d3\\"><span style=\\"color:#000000;background-color:#fdfdfd;\\" class=\\"se-fs-fs24 se-ff-system  se-style-unset \\" id=\\"SE-b1739acb-409a-4a2c-a350-23f27c67454a\\">XL    76/116/102 </span></p><p class=\\"se-text-paragraph se-text-paragraph-align- \\" style=\\"\\" id=\\"SE-3ada445a-b793-4cde-a704-e3360ff935cd\\"><span style=\\"color:#000000;background-color:#fdfdfd;\\" class=\\"se-fs-fs24 se-ff-system  se-style-unset \\" id=\\"SE-bd467d83-6e54-4730-bafd-2009b5dc7807\\">2XL  80/120/103 </span></p><p class=\\"se-text-paragraph se-text-paragraph-align- \\" style=\\"\\" id=\\"SE-67abcd59-50ee-463c-ba93-7215d8170d84\\"><span style=\\"color:#000000;background-color:#fdfdfd;\\" class=\\"se-fs-fs24 se-ff-system  se-style-unset \\" id=\\"SE-cd0f6e49-5d24-491e-85e2-654c6b6004b2\\">3XL  84/124/104 </span></p><p class=\\"se-text-paragraph se-text-paragraph-align- \\" style=\\"\\" id=\\"SE-cb477f98-f534-4d76-a6e3-06df29cfec6f\\"><span style=\\"color:#000000;background-color:#fdfdfd;\\" class=\\"se-fs-fs24 se-ff-system  se-style-unset \\" id=\\"SE-8229603d-4121-4f79-b152-29509a209693\\">4XL  86/126/1058/128/106</span></p><p class=\\"se-text-paragraph se-text-paragraph-align- \\" style=\\"\\" id=\\"SE-a7674ef5-6ed2-4057-9ba9-bc6790418a59\\"><span style=\\"color:#000000;\\" class=\\"se-fs-fs24 se-ff-system  se-style-unset \\" id=\\"SE-ba96b061-e6f3-400b-9243-3556cb93ed88\\">\u200b</span></p><ul class=\\"se-text-list se-text-list-type-bullet-disc\\"><li class=\\"se-text-list-item\\" ><p class=\\"se-text-paragraph se-text-paragraph-align- \\" style=\\"\\" id=\\"SE-5a4a4955-2b10-474a-bb7c-b9f5cdac2c8c\\"><span style=\\"color:#000000;background-color:#fdfdfd;\\" class=\\"se-fs-fs24 se-ff-system  se-style-unset \\" id=\\"SE-f61e52d5-69d9-4b1c-a8d8-4cbcd6d1980e\\">트렌디한 조절이 가능한 코드 디자인. </span></p></li><li class=\\"se-text-list-item\\" ><p class=\\"se-text-paragraph se-tex ...

# %% [markdown]
# # 카테고리 최신화 및 조회

# %%
# 카테고리 리스트 CSV 최신화
# Update_Category_List()

# %%
Update_Category_List()

# %%
[x['name'] for x in get_Major_Categories()]
[x['id'] for x in get_Major_Categories()]

# %%
get_Major_Categories()
# Out:
# [{'wholeCategoryName': '패션의류',
#   'id': '50000000',
#   'name': '패션의류',
#   'last': False},
#  {'wholeCategoryName': '패션잡화',
#   'id': '50000001',
#   'name': '패션잡화',
#   'last': False},
#  {'wholeCategoryName': '화장품/미용',
#   'id': '50000002',
#   'name': '화장품/미용',
#   'last': False},
#  {'wholeCategoryName': '디지털/가전',
#   'id': '50000003',
#   'name': '디지털/가전',
#   'last': False},
#  {'wholeCategoryName': '가구/인테리어',
#   'id': '50000004',
#   'name': '가구/인테리어',
#   'last': False},
#  {'wholeCategoryName': '출산/육아',
#   'id': '50000005',
#   'name': '출산/육아',
#   'last': False},
#  {'wholeCategoryName': '식품', 'id': '50000006', 'name': '식품', 'last': False},
#  {'wholeCategoryName': '스포츠/레저',
#   'id': '50000007',
#   'name': '스포츠/레저',
#   'last': False},
#  {'wholeCategoryName': '생활/건강',
#   'id': '50000008',
#   'name': '생활/건강',
#   'last': False},
#  {'wholeCategoryName': '여가/생활편의',
#   'id': '50000009',
#   'name': '여가/생활편의',
#   'last': False},
#  {'wholeCategoryName': '도서', 'id': '50005542', 'name': '도서', 'last': False}]

# %%
url = Base_url + f"/v1/categories/{50000000}/sub-categories"
headers = { 'Authorization': f"Bearer {access_token+'s'}" }
res = requests.get(url, headers=headers,)
ChildCategories = json.loads(res.text)

# %%
ChildCategories['message']
# Out:
# '요청을 보낼 권한이 없습니다.'

# %%
type(get_Child_Categories("50000000")) == type([])
# Out:
# True

# %%
get_Child_Categories("50000170")
# Out:
# [{'wholeCategoryName': '패션의류>남성언더웨어/잠옷>팬티',
#   'id': '50000845',
#   'name': '팬티',
#   'last': True},
#  {'wholeCategoryName': '패션의류>남성언더웨어/잠옷>러닝',
#   'id': '50000846',
#   'name': '러닝',
#   'last': True},
#  {'wholeCategoryName': '패션의류>남성언더웨어/잠옷>러닝팬티세트',
#   'id': '50000847',
#   'name': '러닝팬티세트',
#   'last': True},
#  {'wholeCategoryName': '패션의류>남성언더웨어/잠옷>잠옷/홈웨어',
#   'id': '50000848',
#   'name': '잠옷/홈웨어',
#   'last': True},
#  {'wholeCategoryName': '패션의류>남성언더웨어/잠옷>시즌성내의',
#   'id': '50001456',
#   'name': '시즌성내의',
#   'last': False},
#  {'wholeCategoryName': '패션의류>남성언더웨어/잠옷>보정속옷',
#   'id': '50001455',
#   'name': '보정속옷',
#   'last': False}]

# %% [markdown]
# ## 브랜드 조회

# %%
find_brand_id('나이키')
# Out:
# [{'id': 1269, 'name': '나이키'},
#  {'id': 34544, 'name': '나이키골프'},
#  {'id': 3404692, 'name': '나이키스윔'},
#  {'id': 20889, 'name': '나이키키즈'}]

# %% [markdown]
# ## 제조사 조회

# %%
find_manufacturers_id('나이키')
# Out:
# [{'id': 259842, 'name': '나이키'}]

# %% [markdown]
# ## 카탈로그 조회

# %%
result = find_catalog_list('나이키 에어맥스97')
# Out:
# [나이키 에어맥스97] 검색 성공 : 100건

# %%
result['contents']
# Out:
# [{'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 31092012848,
#   'name': '에어맥스 97 921826-101'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 19472129052,
#   'name': '에어 맥스 97 921826-001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 45606957618,
#   'name': '에어맥스 97 921826 203'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43315002627,
#   'name': '에어맥스 97 921826 019'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 40989844625,
#   'name': '에어맥스 97 921826 015'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 27930614848,
#   'name': '에어맥스 97 메탈릭실버 페르시안 바이올렛 DJ0717-001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 39284479619,
#   'name': '에어맥스 97 실버 불렛 DM0028-002'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43922028618,
#   'name': '에어맥스 97 SE 신발 FB9619 200'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 45835402619,
#   'name': '에어맥스 97 OG DQ9131 001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 31674402084,
#   'name': '에어맥스 97 트리플블랙 921733-001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 19735676244,
#   'name': '에어맥스 97 BQ4567-001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 45281743620,
#   'name': '에어맥스 97 921826 101'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 39284672619,
#   'name': '에어맥스 97 NH DR0157-001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 24702059475,
#   'name': '에어맥스 97 BQ4567-001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 36195880618,
#   'name': '에어맥스 97 DX0754-001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 42767676622,
#   'name': 'x 꼼데가르송 에어맥스 97 DX6932 002'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43005399621,
#   'name': '에어맥스 97 OG DM0028 400'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 40908688622,
#   'name': '에어맥스 97 921826 109'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43749930619,
#   'name': '에어맥스 97 CI1504 100'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43471562618,
#   'name': '에어맥스 97 SE DM8588 400'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 27954725514,
#   'name': '에어맥스 97 SE DC3986-100'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43475195621,
#   'name': '에어 맥스 97 921826 015'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 33525078201,
#   'name': '에어맥스 97 운동화 DM0027-001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43027385618,
#   'name': '에어맥스 97 OG DM0028 002'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43005833618,
#   'name': '에어맥스 97 페르시안 바이올렛 DJ0717 001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 42280286618,
#   'name': '에어맥스 97 비트루 운동화 FD8637 600'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 31778621963,
#   'name': '에어 맥스 97 DM0027-100'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 39284687621,
#   'name': '에어맥스 97 에센셜 흰빨남 DM2824-100'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43337474620,
#   'name': '에어맥스 97 프리미엄 DV7422 200'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43452676620,
#   'name': '에어맥스 97 DX0754 001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 32863192703,
#   'name': '에어 맥스 97 선 클럽 DM8588-100'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 34405842956,
#   'name': '에어 맥스 97 921826-001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43472900621,
#   'name': '에어 맥스 97 OG DM0028 700'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 33702327861,
#   'name': '에어맥스 97 OG DM0028-001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 32781882805,
#   'name': '에어맥스 97 OG 볼트 아시아 921826-004'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43577708619,
#   'name': '에어 맥스 97 SE DH1085 700'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43580539618,
#   'name': '에어 맥스 97 AJ3053 200'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43455360618,
#   'name': '에어 맥스 97 OG AJ4585 100'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 40888780620,
#   'name': '에어맥스 97 DX4235 001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43580615620,
#   'name': '에어 맥스 97 SE DB0246 001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 39283732625,
#   'name': '에어맥스 97 조지타운 DV7421-001'},
#  {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#   'categoryId': '50003835',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 33211835776,
#   'name': '에어맥스 97 DH8016-100'},
#  {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#   'categoryId': '50003835',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 41898247621,
#   'name': '에어맥스 97 퓨추라 FB4496 001'},
#  {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#   'categoryId': '50003835',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 34861398614,
#   'name': '에어맥스 97 DH8016-002'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 32257359574,
#   'name': '에어맥스 97 OG 남성 러닝화 DM0028400'},
#  {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#   'categoryId': '50003835',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 21237685803,
#   'name': '에어맥스 97 트리플 921733-001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 30567094687,
#   'name': '에어맥스 97 SE DH1085-001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 33558147078,
#   'name': '에어맥스 97 SE DN1893-001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 44677876618,
#   'name': '에어맥스 97 884421 001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43473320619,
#   'name': '에어 맥스 97 OG DM0028 001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 40883896629,
#   'name': '에어맥스 97 OG DM0028 700'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43578418620,
#   'name': '에어 맥스 97 CQ7512 046'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43476089618,
#   'name': '에어 맥스 97 DQ8961 100'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 37442047619,
#   'name': '에어 맥스 97 SE FD0344 397'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43751252621,
#   'name': '에어맥스 97 BQ9130 500'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43854397619,
#   'name': '에어맥스 97 SE  FB9619 001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 44039001621,
#   'name': '에어맥스 97 신발 DZ2629 001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 33262562464,
#   'name': '에어맥스 97 DO8900-100'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 39284076625,
#   'name': '에어맥스 97 SE DV2621-200'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43475584627,
#   'name': '에어 맥스 97 918356 700'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 45036566620,
#   'name': 'x 언디핏 에어맥스 97 AJ1986 001'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 45536723620,
#   'name': '에어맥스 97 CI1503 001'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 45036829619,
#   'name': '에어맥스 97 DM0027 100'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 45261722619,
#   'name': '에어 맥스 97 DC4830 100'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 45792443620,
#   'name': '에어맥스 97 DC1500 001'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 45008538621,
#   'name': '에어맥스 97 CI1508 400'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 44304010622,
#   'name': '에어맥스 97 DV7422 200'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43594178619,
#   'name': '에어 맥스 97 DH8016 600'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43455358619,
#   'name': '에어 맥스 97 AJ4585 101'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 45032440621,
#   'name': '에어맥스 97 SE DV2621 200'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 45032464620,
#   'name': '에어 맥스 97 921826 019'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 15191,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 13460564537,
#   'name': '에어맥스 97 OG 884421-001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 38640983622,
#   'name': '에어맥스 97 운동화 DQ3955-001'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 45539493618,
#   'name': '에어맥스 97 프리미엄 DQ9011 100'},
#  {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#   'categoryId': '50003854',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 36169051620,
#   'name': '에어맥스 97 SE DZ5348-288'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43577822618,
#   'name': '에어 맥스 97 SE DH1085 001'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 44608891623,
#   'name': '에어 맥스 97 FB8454 300'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 45036714621,
#   'name': '에어맥스 97 AJ2614 201'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43751218621,
#   'name': '에어 맥스 97 BQ9130 400'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43578591621,
#   'name': '에어 맥스 97 CQ7512 462'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43577808622,
#   'name': '에어 맥스 97 SE DH4759 001'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43475190636,
#   'name': '에어 맥스 97 918356 001'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 45518824622,
#   'name': '에어맥스 97 312834 200'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 45431794622,
#   'name': '에어맥스 97 921826 016'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43265768618,
#   'name': '에어맥스 97 921522 010'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 45326136627,
#   'name': '에어맥스 97 SE DV2619 100'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 45131381618,
#   'name': '에어 맥스 97 DR9774 400'},
#  {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#   'categoryId': '50000788',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43454733620,
#   'name': '에어 맥스 97 AJ4585 001'},
#  {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#   'categoryId': '50003835',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 44923577619,
#   'name': '에어맥스 97 퓨추라 FB4496 002'},
#  {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#   'categoryId': '50003835',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 29234605233,
#   'name': '에어맥스 97 DH0558-001'},
#  {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#   'categoryId': '50003835',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 44818200618,
#   'name': '에어맥스 97 921522 033'},
#  {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#   'categoryId': '50003835',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43594164620,
#   'name': '에어맥스 97 DH8016 100'},
#  {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#   'categoryId': '50003835',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 38641818618,
#   'name': '에어맥스 97 OG 실버 불렛 DQ9131-002'},
#  {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#   'categoryId': '50003835',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 29615003700,
#   'name': '에어맥스 97 남여공용 DH0558-500'},
#  {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#   'categoryId': '50003835',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 33386365459,
#   'name': '에어 맥스 97 SE 트레이닝화 DX3279-010'},
#  {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#   'categoryId': '50003835',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 35417125621,
#   'name': '에어맥스 97 921733-100'},
#  {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#   'categoryId': '50003835',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 43265733618,
#   'name': '에어맥스 97 921522 011'},
#  {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#   'categoryId': '50003835',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 37020252620,
#   'name': '에어맥스 97 DX0137-600'},
#  {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#   'categoryId': '50003835',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 42571530618,
#   'name': '에어맥스 97 넥스트 DH8016 002'},
#  {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#   'categoryId': '50003835',
#   'manufacturerCode': 259842,
#   'manufacturerName': '나이키',
#   'brandCode': 1269,
#   'brandName': '나이키',
#   'id': 40822082619,
#   'name': '에어맥스 97  FJ5482 100'}]

# %%
get_catalog_record(19472129052)
# Out:
# {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#  'categoryId': '50003854',
#  'manufacturerCode': 259842,
#  'manufacturerName': '나이키',
#  'brandCode': 1269,
#  'brandName': '나이키',
#  'id': 19472129052,
#  'name': '에어 맥스 97 921826-001'}

# %% [markdown]
# ## 원산지 코드 정보

# %%
get_originAreaCode('일본')
# Out:
# '0200036'

# %% [markdown]
# ## 이미지 등록

# %%
image_folder_path = 'image/240119/option/'

image_upload(image_folder_path)
# Out:
# *** 이미지 업로드 성공 ***
# [('레드',
#   'http://shop1.phinf.naver.net/20240122_142/1705929358409wTYVQ_JPEG/5455576275694206_1220525852.jpg'),
#  ('블랙',
#   'http://shop1.phinf.naver.net/20240122_136/1705923655839s4Geh_JPEG/31112929740018466_1265233498.jpg'),
#  ('옐로우',
#   'http://shop1.phinf.naver.net/20240122_150/17059293589071DlnP_JPEG/56280742860303359_1054031388.jpg'),
#  ('화이트',
#   'http://shop1.phinf.naver.net/20240122_112/1705929358680v11dv_JPEG/56541127863940465_1501463376.jpg')]

# %% [markdown]
# # 상품등록

# %% [markdown]
# ### 상품정보등록고시

# %%
# 상품정보등록고시는 로컬에 한번 저장하고, 업데이트 함수를 만들어서 종종 업데이트 하면 됨.
Update_ItemInfoNotification()
# Out:
# *** 상품정보 제공공시 master 업데이트 완료 (ItemInfo_notification.json) ***

# %%
get_ItemInfo_notification_Categories()
# Out:
# *** 상품정보 제공공시 카테고리 리스트 가져오기 성공 ***
# [('의류', 'WEAR'),
#  ('구두/신발', 'SHOES'),
#  ('가방', 'BAG'),
#  ('패션잡화(모자/벨트/액세서리 등)', 'FASHION_ITEMS'),
#  ('침구류/커튼', 'SLEEPING_GEAR'),
#  ('가구(침대/소파/싱크대/DIY제품 등)', 'FURNITURE'),
#  ('영상가전(TV류)', 'IMAGE_APPLIANCES'),
#  ('가정용전기제품(냉장고/세탁기/식기세척기/전자레인지 등)', 'HOME_APPLIANCES'),
#  ('계절가전(에어컨/온풍기 등)', 'SEASON_APPLIANCES'),
#  ('사무용기기(컴퓨터/노트북/프린터 등)', 'OFFICE_APPLIANCES'),
#  ('광학기기(디지털카메라/캠코더 등)', 'OPTICS_APPLIANCES'),
#  ('소형전자(MP3/전자사전 등)', 'MICROELECTRONICS'),
#  ('내비게이션', 'NAVIGATION'),
#  ('자동차용품 (자동차부품/기타 자동차용품 등)', 'CAR_ARTICLES'),
#  ('의료기기', 'MEDICAL_APPLIANCES'),
#  ('주방용품', 'KITCHEN_UTENSILS'),
#  ('화장품', 'COSMETIC'),
#  ('귀금속/보석/시계류', 'JEWELLERY'),
#  ('식품(농.축.수산물)', 'FOOD'),
#  ('가공식품', 'GENERAL_FOOD'),
#  ('건강기능식품', 'DIET_FOOD'),
#  ('어린이제품', 'KIDS'),
#  ('악기', 'MUSICAL_INSTRUMENT'),
#  ('스포츠용품', 'SPORTS_EQUIPMENT'),
#  ('서적', 'BOOKS'),
#  ('물품대여서비스(서적,유아용품,행사용품 등)', 'RENTAL_ETC'),
#  ('디지털콘텐츠(음원,게임,인터넷강의 등)', 'DIGITAL_CONTENTS'),
#  ('상품권/쿠폰', 'GIFT_CARD'),
#  ('모바일쿠폰', 'MOBILE_COUPON'),
#  ('영화/공연', 'MOVIE_SHOW'),
#  ('기타 용역', 'ETC_SERVICE'),
#  ('생활화학제품', 'BIOCHEMISTRY'),
#  ('살생물제품', 'BIOCIDAL'),
#  ('휴대폰 통신기기(휴대폰/태블릿 등)', 'CELLPHONE'),
#  ('기타 재화', 'ETC')]

# %%
# 먼저 카테고리 선택
my_category = 'SHOES'

# %%
get_ItemInfo_notifications('SHOES')
# Out:
# *** SHOES 상품정보 제공공시 항목 가져오기 성공 ***
# [('material', '제품의 주 소재'),
#  ('color', '색상'),
#  ('size', '발길이'),
#  ('height', '굽높이'),
#  ('manufacturer', '제조자(사)'),
#  ('caution', '취급 시 주의사항'),
#  ('warrantyPolicy', '품질 보증 기준'),
#  ('afterServiceDirector', 'A/S 책임자와 전화번호')]

# %%
get_ItemInfo_notifications('WEAR')
# Out:
# *** WEAR 상품정보 제공공시 항목 가져오기 성공 ***
# [('material', '제품 소재'),
#  ('color', '색상'),
#  ('size', '치수'),
#  ('manufacturer', '제조자(사)'),
#  ('caution', '세탁 방법 및 취급 시 주의사항'),
#  ('packDate', '제조연월'),
#  ('packDateText', '제조연월 직접 입력'),
#  ('warrantyPolicy', '품질 보증 기준'),
#  ('afterServiceDirector', 'A/S 책임자와 전화번호')]

# %%
productInfoProvidedNotice = {

}

def lower_string(input_string):
    words = input_string.lower().split('_')
    result = words[0] + ''.join(word.capitalize() for word in words[1:])
    return result

productInfoProvidedNotice['productInfoProvidedNoticeType'] = my_category
productInfoProvidedNotice[lower_string(my_category)] = {
        # 고정 : returnCostReason, noRefundReason, qualityAssuranceStandard, compensationProcedure, troubleShootingContents -> 1: 상품상세 참조
        "returnCostReason": "1", 
        "noRefundReason": "1",
        "qualityAssuranceStandard": "1",
        "compensationProcedure": "1",
        "troubleShootingContents": "1",
    }

# 각 카테고리에 필요한 항목들 입력
productInfoProvidedNotice[lower_string(my_category)]["material"] = "인조 가죽"
productInfoProvidedNotice[lower_string(my_category)]["color"] = "블랙, 화이트, 옐로우, 레드"
productInfoProvidedNotice[lower_string(my_category)]["size"] = "245~280"
productInfoProvidedNotice[lower_string(my_category)]["manufacturer"] = "아식스"
productInfoProvidedNotice[lower_string(my_category)]["caution"] = "상세설명 참조"
productInfoProvidedNotice[lower_string(my_category)]["warrantyPolicy"] = "상세설명 참조"
productInfoProvidedNotice[lower_string(my_category)]["afterServiceDirector"] = "상세설명 참조"

# %%
productInfoProvidedNotice
# Out:
# {'productInfoProvidedNoticeType': 'SHOES',
#  'shoes': {'returnCostReason': '1',
#   'noRefundReason': '1',
#   'qualityAssuranceStandard': '1',
#   'compensationProcedure': '1',
#   'troubleShootingContents': '1',
#   'material': '인조 가죽',
#   'color': '블랙, 화이트, 옐로우, 레드',
#   'size': '245~280',
#   'manufacturer': '아식스',
#   'caution': '상세설명 참조',
#   'warrantyPolicy': '상세설명 참조',
#   'afterServiceDirector': '상세설명 참조'}}

# %% [markdown]
# ### 고정 변수

# %%
get_originAreaCode('일본')
# Out:
# '0200036'

# %%
# AS 정보
afterServiceTelephoneNumber = '010-2936-1595'
afterServiceGuideContent = '상품 오배송 및 파송시 A/S 도와드리겠습니다'

# 판매 기간 정보
saleStartDate = (datetime.datetime.now() + datetime.timedelta(minutes=3)).strftime('%Y-%m-%dT%H:%M:%SZ')  # 현재로부터 3분 뒤
saleEndDate = '2099-01-13T01:30:56Z'

# 세일 기간 정보
# 세일 기간 정보
Discount_StartDate = (datetime.datetime.now() + datetime.timedelta(hours=1)).strftime('%Y-%m-%dT%H')+':00:00Z'  # 현재로부터 다음 정각
Discount_EndDate = '2099-01-13T01:59:00Z'


# 원산지 정보
originAreaInfo_JAPAN = {
"originAreaCode": get_originAreaCode('일본'),
"importer": "japan", # 수입사인 경우 필수
"content": "string",
"plural": True
}

# 부가가치세 타입 : 디폴트는 과세상품 -> TAX(과세 상품), DUTYFREE(면세 상품), SMALL(영세 상품)
taxType =  "TAX"

# %% [markdown]
# #### 입력필요변수

# %%
# 상품이름
name = '아식스 안전화 윈잡 보아 안전 작업화 CP306 1273A029'           
# 상품 상세설명
detailContent = '아식스 안전화 윈잡 보아 안전 작업화 CP306 1273A029 입니다.'

# 판매 가격 (필수)
salePrice = 150000 
# 재고량
stockQuantity = 100

# %%
# 내가 자주 사용하는 카탈로그 dictonary로 만들 필요 있음
find_catalog_list('아식스 안전화 306')  # 카탈로그 확인해서 catalog_Id만 확정하면 나머지 다 따라옴
# Out:
# [아식스 안전화 306] 검색 성공 : 100건
# {'contents': [{'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 42538144516,
#    'name': '아식스 안전화 윈잡 보아 안전 작업화 CP306 1273A029'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45980138820,
#    'name': '아식스 안전화 BOA 남녀공용 작업화 스니커즈 다이얼식 FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 39537568441,
#    'name': '아식스 안전화 윈잡 보아 작업화 23년 CP306 CP304 MAGMA300'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45977945593,
#    'name': '아식스 안전화 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 42732149737,
#    'name': '아식스 안전화 윈잡 보아 남여공용 작업화 FCP306 1273A087'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 41899084761,
#    'name': '아식스 안전화 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 43571093245,
#    'name': '아식스 안전화 윈잡 F 윙죠부 BOA 보아 다이얼 작업화 3종 FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 44254420490,
#    'name': '아식스 안전화 작업화 WINJOB 보아 윈잡 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 37908052155,
#    'name': '아식스 안전화 BOA 윈잡 4인치 다이얼 CP306 1273A029'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 36424782339,
#    'name': '아식스 안전화 BOA Bright x Habanero CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 36425080202,
#    'name': '아식스 안전화 작업화 안전용신발 작업용신발 Winjob BOA CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 42601038779,
#    'name': '아식스 아식스 안전화 윈잡 보아 안전 작업화 CP306 1273A029'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45873111220,
#    'name': '아식스 원잡 보아 안전화 작업화 3E CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 42657993875,
#    'name': '아식스 안전화 작업화 윈잡 F 윙죠부 보아 MAGMA 한정컬러 FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 37495715702,
#    'name': '아식스 안전화 BOA 윈잡 4인치 6인치 CP209 CP306 CP307 CP304'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 42706067012,
#    'name': '아식스 윈잡 보아 BLK 에디션 다이얼 안전화 작업화 CP306 1273A087-001'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45923311952,
#    'name': '아식스 경량 작업 안전화 일본 FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 44978253888,
#    'name': '아식스 안전화 스니커즈 윈잡 BOA BLK EDITION 로우컷 1블랙 크랜베리 25 0 22 크렌베리 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 45415721142,
#    'name': '아식스 안전화 작업화 WINJOB BOA MAGMA CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45085747645,
#    'name': '아식스 안전화 작업화 윈잡 보아 CP306 1273A029 100'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 43584471431,
#    'name': '아식스 안전화 BOA 윈잡 남성 여성 1273A029 FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 35847340728,
#    'name': '아식스 안전화 BOA x CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 45039820278,
#    'name': '아식스 안전화 워크슈즈 BOA 세이프티 FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 44564661084,
#    'name': '아식스 안전화 작업화 컬러 BOA 윈잡 MAGMA FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 26801507132,
#    'name': '다이얼 경량 미끄럼방지 4인치 안전화 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 46002593380,
#    'name': '아식스 안전화 BOA 남녀공용 작업화 스니커즈 다이얼식 FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 45875477664,
#    'name': '아식스 안전화 안전 운동화 윈잡 작업화 상쾌 시트 FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 43881252134,
#    'name': '아식스 원잡 안전화 작업화 에디션 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 42869313986,
#    'name': '아식스 JSAA 규격 윈잡 보아 현장 작업화 안전화 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 43269709901,
#    'name': '아식스 안전화 작업화 모댈 윈잡 윙죠부 BOA 다이얼 F FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 36054112803,
#    'name': '아식스 윈잡 안전화 작업화 보아 2022 3종 23040014428050 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 36496259632,
#    'name': '아식스 윈잡 안전화 작업화 보아 2022 23040014428057 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 35815656128,
#    'name': '아식스 윈잡 안전화 작업화 보아 2022 23040014428052 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandName': '',
#    'id': 43381206995,
#    'name': '아식스 안전화 작업화 로우컷 경량 BOA 블랙에디션 FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45473208957,
#    'name': '아식스 윈잡 보아 안전화 작업화 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 43146660508,
#    'name': '수량제한 아식스 4인치 안전화 보아 다이얼식 크렌베리 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 45511470124,
#    'name': '아식스 안전화 안전 스니커즈 윈잡 일화 스니커즈 상쾌 씨트 부착 FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 44613409562,
#    'name': '아식스 보아 안전화 경량 작업화 마그마 CP306 1273A060'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 43010721511,
#    'name': '아식스 안전화 BOA 윈잡 남여공용 작업용 신발 1273A029 FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 44444585700,
#    'name': '아식스 asics 안전화 작업화 경량 BOA BLK EDITION 305fcp306boab'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 34922703068,
#    'name': '아식스 WINJOB 미끄럼 방지 안전화 작업화 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 42249608164,
#    'name': '아식스 원잡 안전화 보아 4인치 가벼운 발편한 볼넓은 3E 작업화 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandName': '',
#    'id': 44105760027,
#    'name': '아식스 안전화 컬러 BOA 윈잡 MAGMA 남성용 여성 22 5cm-30cm 1273A060 FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 44021552170,
#    'name': '아식스 안전화 윈잡 보아 다이얼 작업화 로우컷 1273A060-300 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 44445336002,
#    'name': '아식스 안전화 작업화 BOA WINJOB -블랙블랙 25 0cm 3E CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 35683883681,
#    'name': '아식스안전화 WINJOB 보아 JSAA C CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 44991627494,
#    'name': '아식스 안전화 asics FCP306 1273A029'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 45499026576,
#    'name': '아식스 안전화 일본 BOA WINJOB ASICS 작업화 워킹화 - 22 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 43339002261,
#    'name': '아식스 안전화 작업화 로우컷 경량 BOA 블랙에디션 FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 35826674898,
#    'name': '아식스 윈잡 안전화 작업화 보아 2022 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 36258630258,
#    'name': '아식스 안전화 작업화 윙잡 퓨즈젤 28 0 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandName': '',
#    'id': 38969305042,
#    'name': '아식스 안전화 작업화 윈잡 보아 메가 CP306 1273A060 020'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 45587234040,
#    'name': '편함 아식스 안전화 cp306 Boa 컬러 맨틀 그린x하바네로 23 030 0c FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 31665601688,
#    'name': '아식스 안전화 작업화 윈잡 보아 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 39095485659,
#    'name': '아식스 윈잡 보아 3E 경량 내유 안전화 작업화 CP306 1273A029-750'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 44445250022,
#    'name': '아식스 안전화 작업화 신발 Winjob BOA BLK EDITION CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 42391750214,
#    'name': '아식스 4인치 보아 안전화 마그마 크랜베리 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 41676872121,
#    'name': '아식스 Winjob 보아 안전화 FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 43014425049,
#    'name': 'ASICS 아식스 안전화 작업용 신발 WINJOB BOA 남여공용 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 43010788651,
#    'name': '아식스 안전화 작업용 현장 신발 윈잡 Boa CP306 1273A029'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 43010010471,
#    'name': '아식스 안전화 작업용 현장신발 윈잡 BOA CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 38742468828,
#    'name': '아식스 안전화 작업화 윈잡 보아 퓨어실버 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 41196399740,
#    'name': '아식스 안전화 작업화 보아 윈잡 윈죠부 마그마 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 44951573358,
#    'name': '아식스 안전화 작업화 윈잡 윙죠부 BOA 보아 다이얼 F 3컬러 FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 45588659164,
#    'name': '아식스 안전화 컬러 다이얼 BOA BLK EDITION 의류 5cm- FCP306 1273A087 22'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 41714097423,
#    'name': '아식스 안전화 윈잡 초 경량 작업화 논슬립 현장 발편한 일본 FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 43568023990,
#    'name': '아식스 안전화 윈잡 BOA 보아 BLK EDITION LOW CUT CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 36276423380,
#    'name': '아식스 안전화 작업화 윙잡 퓨즈젤 클래식 28 0 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 45441601696,
#    'name': '아식스 안전화 경량 윈잡 남녀공용 작업화 WINJOB BOA CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 43079460727,
#    'name': '아식스 안전화 다이얼 경량 발편한 수입 가벼운 작업화 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 45682277832,
#    'name': '아식스 안전화 Boa 컬러 x 일본직배 CP306 1273A029-001'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 43337701197,
#    'name': '아식스 안전화 윈잡 보아 브라이트 - 0cm CP306 1273A029-750 27'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 46141738415,
#    'name': 'asics 아식스 안전화 윈잡 BOA 2023년 모델 작업화 CP306 1273A060'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 46055165430,
#    'name': 'Asics 아식스 안전화 윈 잡 BOA 2023년 모델 CP306 1273A060'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 45546376906,
#    'name': '아식스 안전화 BOA winjob 작업화 5cm-28cm 1273A029 CP306 24'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 44394068595,
#    'name': 'asics 아식스 안전화 일본 경량 야외 작업화 윈잡 Boa CP306 1273A029'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 44446748205,
#    'name': '아식스 안전화 작업화 WINJOB BOA MAGMA Mantle green Habanero CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 45039960088,
#    'name': '아식스 안전화 Boa CP306 1273A029'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 43840629680,
#    'name': '아식스 작업화 안전화 BOA - 001블랙 1273A029 FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 38763729932,
#    'name': '아식스 초 경량 안전화 작업화 논슬립 BOA 003 아빠 선물 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 45662139422,
#    'name': '아식스 보아 원잡 작업화 3컬러 안전화 FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 46155987611,
#    'name': '아식스 안전화 BOA 작업화 여성 남성 22 5cm-30cm 일본직배 FCP306 1273A029'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 44953309495,
#    'name': '아식스 안전화 보아 윈잡 건설화 편한 와이드 볼넓은 세이프티 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 44948790374,
#    'name': '아식스 안전화 보아 작업화 Asics WINJOB 작업 신발 남자 발편한 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 43967159186,
#    'name': 'Asics 아식스 윈잡 보아 다이얼 안전화 작업화 남여공용 CP306 1273A029'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 45754443190,
#    'name': '아식스 안전화 cp306 Boa 컬러 블랙x크랜베리 23 030 0cm 워킹화 세이프티 신 FCP306 CP306 1273A060'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 42775650915,
#    'name': '아식스 안전화 보아 작업화 Asics WINJOB 작업 신발 남자 발편한 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 41556758389,
#    'name': '아식스 안전화 작업화 윈잡 로우컷 보아 1273A029 400 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 44447357413,
#    'name': '아식스 안전화 작업화 WINJOB BOA MAGMA Mantl-맨틀 그린 하바네로 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 38640177169,
#    'name': '아식스 안전화 작업화 윈잡 Boa JSAA 종끝심 내활솔 fuzeGEL 탑재 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 35935121752,
#    'name': '아식스 안전화 작업화 윙잡 퓨즈젤 라이트옐로우 27 5 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 45755493064,
#    'name': '컬러 아식스 안전화 BOA 에디션 BLK EDITION 조금 나쁜 WINJOB아식 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 42323031251,
#    'name': '아식스 Winjob 보아 안전화 F FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 45644772194,
#    'name': '아식스 안전화작업화 윈잡 Boa 화이트클래식 25 5 cm 3E CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 46109120241,
#    'name': '아식스 안전화 스니커즈 윈 잡 BOA BLK EDITION 로우 컷 1 블랙크랜베리 FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 43838342037,
#    'name': '아식스 안전화 Boa 컬러 화이트x클래식 일본직배 CP306 1273A029-100'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 46078835678,
#    'name': '아식스 윈잡 BOA 발편한 경량 작업화 안전화 여성 남성 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 43819593573,
#    'name': '아식스 작업화 안전화 BOA - 100화이트 클래식 1273A029 FCP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 44978259051,
#    'name': '아식스 안전화 윈잡 BOA 작업화 남성 매직테이프 보호 작업 신발 운동화 신발 CP306'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 45588611902,
#    'name': '아식스 안전화 작업화 Boa 피트 시스템 탈착을 빠르고 쉽게 스니커즈 일본직배 CP306'}],
#  'page': 1,
#  'size': 100,
#  'totalElements': 3540,
#  'totalPages': 36,
#  'first': True,
#  'last': False}

# %%
'brandCode' in find_catalog_list('아식스')['contents'][0].keys()
# Out:
# [아식스] 검색 성공 : 100건
# True

# %%
find_catalog_list('아식스')['contents'][0]
# Out:
# [아식스] 검색 성공 : 100건
# {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#  'categoryId': '50003854',
#  'manufacturerCode': 20048,
#  'manufacturerName': '아식스',
#  'brandCode': 654,
#  'brandName': '아식스',
#  'id': 24529441162,
#  'name': '조그 100 2 TJG138-9090'}

# %%
find_catalog_list('아식스')
# Out:
# [아식스] 검색 성공 : 100건
# {'contents': [{'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 24529441162,
#    'name': '조그 100 2 TJG138-9090'},
#   {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#    'categoryId': '50000788',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 31786,
#    'brandName': '오니츠카타이거',
#    'id': 26225654584,
#    'name': '멕시코 66 1183A942 101'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45853823622,
#    'name': '노바블라스트 4 2E 112410203 002'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45938628622,
#    'name': '젤 컨텐드 8 4E 112410220 001'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45897503618,
#    'name': '젤 카야노 30 4E 112330102 001'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45855031619,
#    'name': '노바블라스트 4 2E 112410203 300'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 42673688707,
#    'name': '아식스 안전화 경량 작업화 ASICS 윈잡 일본발송 CP215 1273A079 001'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 21636953221,
#    'name': '아식스 안전화 작업화 윈잡 CP302'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 40635039620,
#    'name': '젤 카야노 14 1202A056 109'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 33361565925,
#    'name': '조그 100T 1022A335-001'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 33228642503,
#    'name': '젤-콘텐드7 4E 112110201-001 볼넓은 남성 여성 런닝화 GEL-CONTEND7'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 10664170626,
#    'name': '러닝화 TVRA03-0150'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45855124620,
#    'name': '젤 카야노 30 112410103 102'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 32127312017,
#    'name': '젤 카야노 28 112130102-401'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45854820622,
#    'name': '조그 100T 112219266 021'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 40636565619,
#    'name': '젤 벤쳐6 SPS 버치1203A239 200'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 25695190098,
#    'name': '젤 1090 W 1022A215-100'},
#   {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#    'categoryId': '50003835',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 30479663530,
#    'name': '젤 컨텐드 7 W 112210217-027'},
#   {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#    'categoryId': '50000788',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 44676688619,
#    'name': 'x 아트모스 x 오호스 젤 1130 RE 1203A429 020'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 29567564235,
#    'name': '조그 100S 1201A325-100'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 44751991844,
#    'name': '아식스 초 경량 안전화 작업화 논슬립 아빠 선물 CP215'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 43433336139,
#    'name': '아식스 윈잡 UTSUROI 안전화 3E 작업화 6인치 경량 CP120 1273A085 001'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 41219821294,
#    'name': '아식스 윈잡 3E F -9090 하이컷 6인치 벨크로 안전화 작업화 FCP302-9090'},
#   {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#    'categoryId': '50003835',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45897518620,
#    'name': '젤 컨텐드 7 D 112130214 001'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 25643491793,
#    'name': '타사 재팬 TARTHER JAPAN 2018 런닝화 1013A007-100'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45855113621,
#    'name': '젤 님버스 26 2E 112410212 002'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45855081619,
#    'name': '젤 카야노 30 4E 112410101 001'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 40537353644,
#    'name': '안전화 작업화 JSAA A CP302'},
#   {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#    'categoryId': '50003835',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45854820620,
#    'name': '젤 님버스 26 W D 112410214 002'},
#   {'wholeCategoryName': '패션잡화>여성신발>단화>스니커즈',
#    'categoryId': '50003822',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 42745146618,
#    'name': '마뗑킴 젤 소노마 15 50 오아시스 1202A461 300'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 31726691527,
#    'name': '젤 1130 폴라 쉐이드 실버'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 34292404192,
#    'name': '젤1130 오이스터 1201A256-025 그레이 클레이'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 31710240007,
#    'name': '젤 1130 112219309-100'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 44470897923,
#    'name': '아식스 초 경량 안전화 작업화 논슬립 아빠 선물 CP302'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 42821568489,
#    'name': '아식스 안전화 윈잡 작업화 BOA 하이탑 BLK EDITION 일본 정규품 CP603'},
#   {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#    'categoryId': '50000788',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 31786,
#    'brandName': '오니츠카타이거',
#    'id': 7716918954,
#    'name': '멕시코66 스니커즈 DL408  0146'},
#   {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#    'categoryId': '50003835',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45854930618,
#    'name': '젤 님버스 26 W 112410215 100'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 20103765129,
#    'name': '조그 100 2 TJG138-9090'},
#   {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#    'categoryId': '50003835',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45853228620,
#    'name': '노바블라스트 4  D 112410205 250'},
#   {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#    'categoryId': '50003835',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 34323657421,
#    'name': '젤 카야노 14 1201A457-101'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 24088468891,
#    'name': '안전화 작업화 FCP201'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 26639523875,
#    'name': '아식스 경량 안전화 4인치 작업화 3416949236 WX-0007'},
#   {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#    'categoryId': '50003835',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 33782649372,
#    'name': '젤 컨텐드 7 1012A910-001'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 33655202426,
#    'name': '젤 벤쳐 6 SPS 글레이셔 그레이 1201A553-021'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45855119619,
#    'name': '젤 님버스 26 4E 112410211 400'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45855084619,
#    'name': '젤 님버스 26 112410213 100'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45897653618,
#    'name': '젤 카야노 30 112330101 401'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 43027034618,
#    'name': '프레자 위워 젤 1090 V2 1203A254 020'},
#   {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#    'categoryId': '50000788',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 34458210122,
#    'name': '코트 S 1201A695-100'},
#   {'wholeCategoryName': '패션잡화>여성신발>운동화>워킹화',
#    'categoryId': '50003839',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 37445867620,
#    'name': '젤 컨텐드 8 1012B320 001'},
#   {'wholeCategoryName': '패션잡화>여성신발>단화>스니커즈',
#    'categoryId': '50003822',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 42647252619,
#    'name': '마뗑킴 젤 소노마 1202A487 020'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45855123618,
#    'name': '젤 카야노 30 112410103 101'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45855114618,
#    'name': '노바블라스트 4 112410204 400'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45855119618,
#    'name': '젤 님버스 26 2E 112410212 020'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45897659620,
#    'name': '젤 컨텐드 8 112310217 007'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 30697213661,
#    'name': '젤 1130 112139306-002'},
#   {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#    'categoryId': '50003835',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 42571435618,
#    'name': '젤 1130 1202A164 107'},
#   {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#    'categoryId': '50003835',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 37442666618,
#    'name': '젤 카야노 29 D 1012B297 404'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 31278303670,
#    'name': '젤 컨텐드 7-W 1012A911-012'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 26396085661,
#    'name': '운동화 JOG 100S FQ 1201A325-001'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45761971361,
#    'name': '아식스 안전화 작업화 CP201'},
#   {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#    'categoryId': '50000788',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 43044067618,
#    'name': '세실리에 반센 GT 2160 1203A321 100'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45855082620,
#    'name': '조그 100S 112339319 100'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45938656619,
#    'name': '젤 컨텐드 8 112410221 104'},
#   {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#    'categoryId': '50000788',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 46098863620,
#    'name': 'x C P 컴퍼니 젤 퀀텀 360 8 1203A507 020'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45854642619,
#    'name': '젤 카야노29 D W 112310104 403'},
#   {'wholeCategoryName': '패션잡화>남성신발>슬립온',
#    'categoryId': '50000783',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 31786,
#    'brandName': '오니츠카타이거',
#    'id': 37153386827,
#    'name': '멕시코 66 슬립온 212137042 101'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45528054167,
#    'name': '아식스 안전화 작업화 asics 윈잡 - 24 5 cm CP112 1273A056'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 46097258619,
#    'name': '젤 님버스 9 1201A424 105'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 43451287618,
#    'name': '조그 100 2 TJG138 9090'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45897658620,
#    'name': '젤 카야노29 112310101 403'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45897660618,
#    'name': '졸트 3 W D 112130202 504'},
#   {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#    'categoryId': '50000788',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 31786,
#    'brandName': '오니츠카타이거',
#    'id': 45976466620,
#    'name': '캘리포니아 78 EX 1183B410 200'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45855078619,
#    'name': '젤 컨텐드 8 8 112330217 408'},
#   {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#    'categoryId': '50000788',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 31786,
#    'brandName': '오니츠카타이거',
#    'id': 45975355619,
#    'name': '멕시코 66 1183C102 200'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45855113622,
#    'name': '젤 벤쳐 9 워터프루프 112330306 020'},
#   {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#    'categoryId': '50000788',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 46099941619,
#    'name': '젤 퀀텀 키네틱 1203A270 023'},
#   {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#    'categoryId': '50003835',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45937925623,
#    'name': '젤 컨텐드 8 D 112410222 013'},
#   {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#    'categoryId': '50000788',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 46097956620,
#    'name': '젤 퀀텀 키네틱 미드 1203A270 022'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 46098257618,
#    'name': '젤 벤처 6 SPS 1203A297 022'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 46097305623,
#    'name': '젤 1130 1201A256 116'},
#   {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#    'categoryId': '50000788',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45006964619,
#    'name': '타이거 젤 PTG HL7X0 0190'},
#   {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#    'categoryId': '50003835',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45897666619,
#    'name': '노바블라스트 4 112410206 100'},
#   {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#    'categoryId': '50000788',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 43212517618,
#    'name': '젤 1130 1201A995 200'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45897664618,
#    'name': 'UN1 S 조거 X81 112219314 200'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 26043097453,
#    'name': '헤리티지 스포츠스타일 스니커즈 젤-1090 112119301-200'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandName': '',
#    'id': 35674951309,
#    'name': 'ASICS 아식스 남성용 안전화 윈잡 JSAA 작업용 CP201'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45854198620,
#    'name': '젤 컨텐드 8 112330241 103'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45978104566,
#    'name': '아식스 6인치 경량 현장 발볼넓은 발편한 보아 다이얼 작업화 안전화 CP304'},
#   {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#    'categoryId': '50003835',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 43117506618,
#    'name': '젤 1130 1202A164 110'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45855117620,
#    'name': '젤 컨텐드 8 112330217 011'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 41867598827,
#    'name': '아식스 안전화 윈잡 보아 다이얼 작업화 하이컷 발볼 3E F 255 FCP304 255'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 43576494618,
#    'name': '젤 1130 폴라 쉐이드 1201A256 021'},
#   {'wholeCategoryName': '패션잡화>남성신발>기능화>작업화/안전화',
#    'categoryId': '50003860',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 37490492183,
#    'name': '아식스 초 경량 안전화 작업화 논슬립 아빠 선물 CP113 001'},
#   {'wholeCategoryName': '패션잡화>여성신발>운동화>러닝화',
#    'categoryId': '50003835',
#    'manufacturerCode': 0,
#    'manufacturerName': '',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 21671428062,
#    'name': '졸트2 어글리슈즈 여성 런닝화'},
#   {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#    'categoryId': '50000788',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 31786,
#    'brandName': '오니츠카타이거',
#    'id': 45974937618,
#    'name': '멕시코 66 VIN SD 1183C015 101'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 45854254620,
#    'name': '젤 카야노 30 112410103 402'},
#   {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#    'categoryId': '50000788',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 31786,
#    'brandName': '오니츠카타이거',
#    'id': 45974855620,
#    'name': 'GSM SD 1183A803 101'},
#   {'wholeCategoryName': '패션잡화>남성신발>스니커즈',
#    'categoryId': '50000788',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 46101241619,
#    'name': 'x 페이퍼걸 파리 x 빔즈 GT 2160 1203A427 100'},
#   {'wholeCategoryName': '패션잡화>남성신발>운동화>러닝화',
#    'categoryId': '50003854',
#    'manufacturerCode': 20048,
#    'manufacturerName': '아식스',
#    'brandCode': 654,
#    'brandName': '아식스',
#    'id': 46098837620,
#    'name': '젤 벤쳐 6 SPS 1203A297 200'}],
#  'page': 1,
#  'size': 100,
#  'totalElements': 40063,
#  'totalPages': 401,
#  'first': True,
#  'last': False}

# %%
# https://www.amazon.co.jp/%E3%82%A2%E3%82%B7%E3%83%83%E3%82%AF%E3%82%B9-%E3%83%AF%E3%83%BC%E3%82%AD%E3%83%B3%E3%82%B0-%E3%82%A6%E3%82%A3%E3%83%B3%E3%82%B8%E3%83%A7%E3%83%96-CP306-fuzeGEL%E6%90%AD%E8%BC%89/dp/B081JSHJT8/ref=sr_1_41?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&crid=I12PM0M11J21&keywords=boa&qid=1705930553&sprefix=boa%2Caps%2C207&sr=8-41

# %%
# 카테고리 id를 먼저 지정해야함 -> 카탈로그로 인해 나중에 바뀔수도 있지만.
leafCategoryId = ''




# 카탈로그 id 활용해서 얻을 수 있음.  ** 없는 경우: 직접 입력    
catalog_Id = '42538144516'

recode = get_catalog_record(catalog_Id)
leafCategoryId = recode['categoryId']             
catalog_Name = recode['name']
manufacturerName =  recode['manufacturerName']      # find_manufacturers_id('나이키') # 활용 -> 존재하는지 여부 확인
brandId = recode['brandCode']                       # find_brand_id('나이키') # 활용  -> 브랜드 ID 확인
brandName = recode['brandName']    


naverShoppingSearchInfo = {
        "modelId": catalog_Id,
        "modelName": catalog_Name,
        "manufacturerName": manufacturerName,
        "brandId": brandId,
        "brandName": brandName
      }

# %%
# ImageUrl_option = image_upload('image/240119/option/')
# options_size = [ str(225+ n*5) for n in range(16) ]       # 사이즈
# options_2 = [x[0] for x in ImageUrl_option]
# Out:
# *** 이미지 업로드 성공 ***

# %%
get_standard_attribute_names('50000000')
# Out:
# *** [leafCategoryId: 50000000] 카테고리의 표준 옵션 클래스 리스트 가져오기 실패 ***

# %%
leafCategoryId
# Out:
# '50003860'

# %%
url = Base_url + f'/v1/options/standard-options?categoryId=50000000'
headers = {'Authorization': f'Bearer {access_token}'}
res = requests.get(url = url, headers=headers)
        
# 표준 옵션 목록
standard_option_classes = json.loads(res.text)

# %%
standard_option_classes['useStandardOption']
# Out:
# False

# %%
standard_option_classes
# Out:
# {'useStandardOption': True,
#  'standardOptionCategoryGroups': [{'attributeId': 10014204,
#    'attributeName': '사이즈(한국)',
#    'groupName': '사이즈',
#    'imageRegistrationUsable': False,
#    'realValueUsable': False,
#    'optionSetRequired': True,
#    'standardOptionAttributes': [{'attributeId': 10014204,
#      'attributeValueId': 10696132,
#      'attributeValueName': '210'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10696133,
#      'attributeValueName': '215'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10696134,
#      'attributeValueName': '220'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10696136,
#      'attributeValueName': '225'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10696137,
#      'attributeValueName': '230'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10696138,
#      'attributeValueName': '235'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10696139,
#      'attributeValueName': '240'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10696140,
#      'attributeValueName': '245'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10696141,
#      'attributeValueName': '250'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10696142,
#      'attributeValueName': '255'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10696143,
#      'attributeValueName': '260'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10696144,
#      'attributeValueName': '265'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10696145,
#      'attributeValueName': '270'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10696146,
#      'attributeValueName': '275'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10696147,
#      'attributeValueName': '280'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10696148,
#      'attributeValueName': '285'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10696149,
#      'attributeValueName': '290'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10696150,
#      'attributeValueName': '295'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10696151,
#      'attributeValueName': '300'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10696152,
#      'attributeValueName': '305'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10696153,
#      'attributeValueName': '310'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10765971,
#      'attributeValueName': 'one size'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10834617,
#      'attributeValueName': 'Free'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10443624,
#      'attributeValueName': 'S'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10031499,
#      'attributeValueName': 'M'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10443630,
#      'attributeValueName': 'L'},
#     {'attributeId': 10014204,
#      'attributeValueId': 10031501,
#      'attributeValueName': 'XL'}]},
#   {'attributeId': 10014205,
#    'attributeName': '사이즈(미국)',
#    'groupName': '사이즈',
#    'imageRegistrationUsable': False,
#    'realValueUsable': False,
#    'optionSetRequired': True,
#    'standardOptionAttributes': [{'attributeId': 10014205,
#      'attributeValueId': 10776793,
#      'attributeValueName': 'US 3'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10776794,
#      'attributeValueName': 'US 3.5'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10772854,
#      'attributeValueName': 'US 4'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10776795,
#      'attributeValueName': 'US 4.5'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10765972,
#      'attributeValueName': 'US 5'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10765973,
#      'attributeValueName': 'US 5.5'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10765974,
#      'attributeValueName': 'US 6'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10765975,
#      'attributeValueName': 'US 6.5'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10765976,
#      'attributeValueName': 'US 7'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10765977,
#      'attributeValueName': 'US 7.5'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10765978,
#      'attributeValueName': 'US 8'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10765979,
#      'attributeValueName': 'US 8.5'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10765980,
#      'attributeValueName': 'US 9'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10765981,
#      'attributeValueName': 'US 9.5'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10765982,
#      'attributeValueName': 'US 10'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10765983,
#      'attributeValueName': 'US 10.5'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10765984,
#      'attributeValueName': 'US 11'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10765985,
#      'attributeValueName': 'US 11.5'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10765986,
#      'attributeValueName': 'US 12'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10765987,
#      'attributeValueName': 'US 12.5'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10765988,
#      'attributeValueName': 'US 13'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10765971,
#      'attributeValueName': 'one size'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10834617,
#      'attributeValueName': 'Free'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10443624,
#      'attributeValueName': 'S'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10031499,
#      'attributeValueName': 'M'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10443630,
#      'attributeValueName': 'L'},
#     {'attributeId': 10014205,
#      'attributeValueId': 10031501,
#      'attributeValueName': 'XL'}]},
#   {'attributeId': 10014206,
#    'attributeName': '사이즈(유럽)',
#    'groupName': '사이즈',
#    'imageRegistrationUsable': False,
#    'realValueUsable': False,
#    'optionSetRequired': True,
#    'standardOptionAttributes': [{'attributeId': 10014206,
#      'attributeValueId': 10771424,
#      'attributeValueName': 'EU 34'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10776829,
#      'attributeValueName': 'EU 34.5'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10771425,
#      'attributeValueName': 'EU 35'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10771426,
#      'attributeValueName': 'EU 35.5'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10765989,
#      'attributeValueName': 'EU 36'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10765990,
#      'attributeValueName': 'EU 36.5'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10765991,
#      'attributeValueName': 'EU 37'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10765992,
#      'attributeValueName': 'EU 37.5'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10765993,
#      'attributeValueName': 'EU 38'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10765994,
#      'attributeValueName': 'EU 38.5'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10765995,
#      'attributeValueName': 'EU 39'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10765996,
#      'attributeValueName': 'EU 39.5'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10765997,
#      'attributeValueName': 'EU 40'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10765998,
#      'attributeValueName': 'EU 40.5'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10765999,
#      'attributeValueName': 'EU 41'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10766000,
#      'attributeValueName': 'EU 41.5'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10766001,
#      'attributeValueName': 'EU 42'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10766002,
#      'attributeValueName': 'EU 42.5'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10766003,
#      'attributeValueName': 'EU 43'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10766004,
#      'attributeValueName': 'EU 43.5'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10766005,
#      'attributeValueName': 'EU 44'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10766006,
#      'attributeValueName': 'EU 44.5'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10766007,
#      'attributeValueName': 'EU 45'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10766008,
#      'attributeValueName': 'EU 45.5'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10765971,
#      'attributeValueName': 'one size'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10834617,
#      'attributeValueName': 'Free'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10443624,
#      'attributeValueName': 'S'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10031499,
#      'attributeValueName': 'M'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10443630,
#      'attributeValueName': 'L'},
#     {'attributeId': 10014206,
#      'attributeValueId': 10031501,
#      'attributeValueName': 'XL'}]},
#   {'attributeId': 10014207,
#    'attributeName': '사이즈(영국)',
#    'groupName': '사이즈',
#    'imageRegistrationUsable': False,
#    'realValueUsable': False,
#    'optionSetRequired': True,
#    'standardOptionAttributes': [{'attributeId': 10014207,
#      'attributeValueId': 10766009,
#      'attributeValueName': 'UK 2.5'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10766010,
#      'attributeValueName': 'UK 3'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10766011,
#      'attributeValueName': 'UK 3.5'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10766012,
#      'attributeValueName': 'UK 4'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10766013,
#      'attributeValueName': 'UK 4.5'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10766014,
#      'attributeValueName': 'UK 5'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10766015,
#      'attributeValueName': 'UK 5.5'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10766016,
#      'attributeValueName': 'UK 6'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10766017,
#      'attributeValueName': 'UK 6.5'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10766018,
#      'attributeValueName': 'UK 7'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10766019,
#      'attributeValueName': 'UK 7.5'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10766020,
#      'attributeValueName': 'UK 8'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10766021,
#      'attributeValueName': 'UK 8.5'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10766022,
#      'attributeValueName': 'UK 9'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10766023,
#      'attributeValueName': 'UK 9.5'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10766024,
#      'attributeValueName': 'UK 10'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10766025,
#      'attributeValueName': 'UK 10.5'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10766026,
#      'attributeValueName': 'UK 11'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10766027,
#      'attributeValueName': 'UK 11.5'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10766028,
#      'attributeValueName': 'UK 12'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10766029,
#      'attributeValueName': 'UK 12.5'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10765971,
#      'attributeValueName': 'one size'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10834617,
#      'attributeValueName': 'Free'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10443624,
#      'attributeValueName': 'S'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10031499,
#      'attributeValueName': 'M'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10443630,
#      'attributeValueName': 'L'},
#     {'attributeId': 10014207,
#      'attributeValueId': 10031501,
#      'attributeValueName': 'XL'}]},
#   {'attributeId': 10014203,
#    'attributeName': '색상',
#    'groupName': '색상',
#    'imageRegistrationUsable': True,
#    'realValueUsable': True,
#    'optionSetRequired': True,
#    'standardOptionAttributes': [{'attributeId': 10014203,
#      'attributeValueId': 10031739,
#      'attributeValueName': '레드',
#      'attributeColorCode': '#FF0000'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10671461,
#      'attributeValueName': '버건디',
#      'attributeColorCode': '#A62C54'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10031736,
#      'attributeValueName': '오렌지',
#      'attributeColorCode': '#FFA500'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10197443,
#      'attributeValueName': '골드',
#      'attributeColorCode': '#FFD700'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10031742,
#      'attributeValueName': '옐로우',
#      'attributeColorCode': '#FFFF00'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10669310,
#      'attributeValueName': '라임',
#      'attributeColorCode': '#AAF543'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10533144,
#      'attributeValueName': '그린',
#      'attributeColorCode': '#36B401'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10031743,
#      'attributeValueName': '카키',
#      'attributeColorCode': '#71842F'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10531885,
#      'attributeValueName': '민트',
#      'attributeColorCode': '#71ECDC'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10669048,
#      'attributeValueName': '스카이블루',
#      'attributeColorCode': '#87CEEB'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10031731,
#      'attributeValueName': '블루',
#      'attributeColorCode': '#0000FF'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10031732,
#      'attributeValueName': '네이비',
#      'attributeColorCode': '#000080'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10031738,
#      'attributeValueName': '퍼플',
#      'attributeColorCode': '#800080'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10545495,
#      'attributeValueName': '바이올렛',
#      'attributeColorCode': '#8865E0'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10241290,
#      'attributeValueName': '핑크',
#      'attributeColorCode': '#FFC0CB'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10411187,
#      'attributeValueName': '핫핑크',
#      'attributeColorCode': '#F7027C'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10241293,
#      'attributeValueName': '베이지',
#      'attributeColorCode': '#F4D6A1'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10696336,
#      'attributeValueName': '카멜',
#      'attributeColorCode': '#D6855A'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10531874,
#      'attributeValueName': '브라운',
#      'attributeColorCode': '#8B4513'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10531869,
#      'attributeValueName': '화이트',
#      'attributeColorCode': 'color-type-white'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10531875,
#      'attributeValueName': '아이보리',
#      'attributeColorCode': '#F2EFDE'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10031729,
#      'attributeValueName': '실버',
#      'attributeColorCode': '#C0C0C0'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10040013,
#      'attributeValueName': '그레이',
#      'attributeColorCode': '#808080'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10679194,
#      'attributeValueName': '차콜',
#      'attributeColorCode': '#4A515F'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10031727,
#      'attributeValueName': '블랙',
#      'attributeColorCode': '#000000'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10199545,
#      'attributeValueName': '투명',
#      'attributeColorCode': 'color-type-trans'},
#     {'attributeId': 10014203,
#      'attributeValueId': 10674946,
#      'attributeValueName': '멀티',
#      'attributeColorCode': 'color-type-multi'}]}]}

# %%
get_standard_attribute_names(leafCategoryId)
# Out:
# *** [leafCategoryId: 50003860] 카테고리의 표준 옵션 클래스 리스트 가져오기 성공 ***
# ['사이즈(한국)', '사이즈(미국)', '사이즈(유럽)', '사이즈(영국)', '색상']

# %%
get_standard_attribute(leafCategoryId, '사이즈(한국)',  options_1 )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_standard_attribute(leafCategoryId, '사이즈(한국)',  options_size )
#
# NameError: name 'leafCategoryId' is not defined

# %%
get_standard_attribute(leafCategoryId, '색상',  options_2 )
# Out:
# *** [leafCategoryId: 50003860] 카테고리의 색상 표준 옵션 가져오기 성공 ***
# [{'attributeId': 10014203,
#   'attributeValueId': 10031739,
#   'attributeValueName': '레드',
#   'attributeColorCode': '#FF0000'},
#  {'attributeId': 10014203,
#   'attributeValueId': 10031742,
#   'attributeValueName': '옐로우',
#   'attributeColorCode': '#FFFF00'},
#  {'attributeId': 10014203,
#   'attributeValueId': 10531869,
#   'attributeValueName': '화이트',
#   'attributeColorCode': 'color-type-white'},
#  {'attributeId': 10014203,
#   'attributeValueId': 10031727,
#   'attributeValueName': '블랙',
#   'attributeColorCode': '#000000'}]

# %% [markdown]
# 신발 옵션

# %%
# 이미지 등록 : 메인 이미지, 추가이미지, 옵션 이미지
ImageUrl_Main   = image_upload('image/240119/main/')
ImageUrl_Extra  = image_upload('image/240119/extra/')
ImageUrl_option = image_upload('image/240119/option/')

# 대표이미지 URL
representativeImageURL = ImageUrl_Main[0][1] # 블랙
# 추가 이미지 URL 목록
optionalImagesURLs = [ {"url": x[1]} for x in ImageUrl_Extra]


# 옵션 이미지 등록 
options_1 = [ str(225+ n*5) for n in range(16) ]       # 사이즈
options_2 = [x[0] for x in ImageUrl_option]

standard_attribute_1 = get_standard_attribute(leafCategoryId, '사이즈(한국)',  options_1 )     
standard_attribute_2 = get_standard_attribute(leafCategoryId, '색상',  options_2 )     


OptionGroup1 =  {
        "groupName" : "색상",
        "standardOptionAttributes" : [ 
            {
             "attributeId": color['attributeId'],
             "attributeValueId": color['attributeValueId'],
             "attributeValueName": color['attributeValueName'],
             "imageUrls": ImageUrl_option[idx][1]
             }
            for idx, color in enumerate(standard_attribute_2)
        ]
      }

OptionGroup2 = {
        "groupName" : "사이즈",
        "standardOptionAttributes" : [
            {
             "attributeId": size['attributeId'],
             "attributeValueId": size['attributeValueId'],
             "attributeValueName": size['attributeValueName'],
             }
             for idx, size in enumerate(standard_attribute_1)
             
        ]
      }
# Out:
# *** 이미지 업로드 성공 ***
# *** 이미지 업로드 성공 ***
# *** [leafCategoryId: 50003860] 카테고리의 사이즈(한국) 표준 옵션 가져오기 성공 ***
# *** [leafCategoryId: 50003860] 카테고리의 색상 표준 옵션 가져오기 성공 ***

# %%
OptionGroup1
# Out:
# {'groupName': '색상',
#  'standardOptionAttributes': [{'attributeId': 10014203,
#    'attributeValueId': 10031739,
#    'attributeValueName': '레드',
#    'imageUrls': 'http://shop1.phinf.naver.net/20240122_142/1705929358409wTYVQ_JPEG/5455576275694206_1220525852.jpg'},
#   {'attributeId': 10014203,
#    'attributeValueId': 10031742,
#    'attributeValueName': '옐로우',
#    'imageUrls': 'http://shop1.phinf.naver.net/20240122_136/1705923655839s4Geh_JPEG/31112929740018466_1265233498.jpg'},
#   {'attributeId': 10014203,
#    'attributeValueId': 10531869,
#    'attributeValueName': '화이트',
#    'imageUrls': 'http://shop1.phinf.naver.net/20240122_150/17059293589071DlnP_JPEG/56280742860303359_1054031388.jpg'},
#   {'attributeId': 10014203,
#    'attributeValueId': 10031727,
#    'attributeValueName': '블랙',
#    'imageUrls': 'http://shop1.phinf.naver.net/20240122_112/1705929358680v11dv_JPEG/56541127863940465_1501463376.jpg'}]}

# %%
items = [[x[0] for x in ImageUrl_option], options_1]

# 옵션 매칭
optionStandards =  [
              {
                    "id": idx+1,
                    "optionName1": f"{combi[0]}",
                    "optionName2": f"{combi[1]}",
                    "stockQuantity": 9999,
                    "usable": True
                }
                for idx, combi in enumerate(list(product(*items)))
                
  ] 


# 조합형으로 수정 필요
simpleOption_template = { 
    "simpleOptionSortType": "CREATE",
    "optionSimple": [ ],
    "optionCombinationSortType": "CREATE",
    # 표준형 옵션 그룹 : 그룹 네임과 옵션 속성들 
    "standardOptionGroups" : [
     OptionGroup1,
     OptionGroup2
    ],
    "optionStandards":  optionStandards,

    "useStockManagement": False                    # 옵션 재고 수량 관리 사용 여부
}

optionInfo = simpleOption_template

# %%
# # 구매수량 
# purchaseQuantityInfo =  {
#     "minPurchaseQuantity": 1,           # 최소 구매 수량
#     "maxPurchaseQuantityPerId": 100,    # 1인 최대 구매수량
#     "maxPurchaseQuantityPerOrder": 100  # 1회 최대 구매수량
# }


# 제조일자 : 인증 유형이 방송통신기자재 적합인증/적합등록/잠정인증인 경우 필수. 'yyyy-MM-dd' 형식 입력.
manufactureDate =  '2023-11-01' # "yyyy-mm-dd" 형태

# # 출시일자: 브랜드 스토어 한정, 수정불가
# releaseDate = '' # "yyyy-mm-dd" 형태

# 유효일자: 
validDate = '2033-11-01'   # "yyyy-mm-dd" 형태




productCertificationInfos = [
        # {
        #   "certificationInfoId": 0,                        # 인증유형
        #   "certificationKindType": "OVERSEAS",             # 인증정보종류코드 : KC_CERTIFICATION(KC 인증), CHILD_CERTIFICATION(어린이제품 인증), GREEN_PRODUCTS(친환경 인증), OVERSEAS(구매대행(구매대행 선택 시 인증 정보 필수 등록)), PARALLEL_IMPORT(병행수입(병행수입 선택 시 인증 정보 필수 등록)), ETC(기타 인증)
        #   "name": "string",                                # 인증기관명
        #   "certificationNumber": "string",                 # 인증번호
        #   "certificationMark": True,                       # 인증마크 사용 여부 - 디폴트는 false
        #   "companyName": "string",                         # 인증 상호명
        #   "certificationDate": "2024-01-13"                # 인증 일자
        # }
      ]

certificationTargetExcludeContent =  {
    "childCertifiedProductExclusionYn": True,                     # 어린이제품 인증 대상 제외 여부: 필수. 미입력 시 false로 저장됩니다
    "kcExemptionType": "OVERSEAS",                                # KC 면제 대상 타입  (구매대행/병행이면 필수 입력): SAFE_CRITERION(안전기준준수대상(안전기준준수대상 예외 카테고리가 아닌 경우에도 설정 가능, 식품 카테고리 외)), OVERSEAS(구매대행), PARALLEL_IMPORT(병행수입)
    "kcCertifiedProductExclusionYn": "KC_EXEMPTION_OBJECT",       # TRUE(KC 인증 대상 아님), FALSE(KC 인증 대상), KC_EXEMPTION_OBJECT(안전기준준수, 구매대행, 병행수입인 경우 필수 입력)
    "greenCertifiedProductExclusionYn": True                      # 친환경 인증 대상 제외 여부
  },

# 미성년자 사용 가능 여부
minorPurchasable =  True

# 상품정보제공고시
productInfoProvidedNoticeType = 'WEAR'




# 문화비 소득공제 여부: 예외 카테고리 중 도서_일반, 도서_해외, 도서_중고, 도서_E북, 도서_오디오북, 문화비_소득공제에 해당하는 경우 입력할 수 있습니다. 미입력 시 false로 저장됩니다.
cultureCostIncomeDeductionYn = False

# 맞춤 제작 상품 여부
customProductYn = False
# 자체 제작 상품 여부
itselfProductionProductYn =  False
# 브랜드 인증 여부
# brandCertificationYn = True
# (SEO(Search engine optimization) 정보)
# pageTitle/metaDescription : 상품 정보를 SNS 등 소셜 서비스에 공유 시 검색 최적화를 위한 기능으로 검색에 활용될 수 있도록 설정할 수 있습니다.
pageTitle = "title태그"
metaDescription = "한줄 설명"
tags = []

seoInfo = {
  "pageTitle": pageTitle,
  "metaDescription": metaDescription,
  "sellerTags": [{ "code": idx, "text": tag } for idx,tag in enumerate(tags)]
}


discount_unitType = 'PERCENT' # 할인 단위 타입 ->  PERCENT, WON만 입력 가능합니다.
discount_value  = '10'        # 할인 단위에 따른 값을 입력합니다.
discount_startDate = saleStartDate
discount_endDate = saleEndDate

# %%
deliveryInfo = {
      "deliveryType": "DELIVERY",                  # DELIVERY(택배, 소포, 등기), DIRECT(직접배송(화물배달))
      "deliveryAttributeType": "NORMAL",
      "deliveryCompany": "EPOST",
      "deliveryBundleGroupUsable": True,
      # "deliveryBundleGroupId": 0,
      "deliveryFee": {
        "deliveryFeeType": "PAID",
        "baseFee": 4000,
        "deliveryFeePayType": "PREPAID",
        "deliveryFeeByArea": {
          "deliveryAreaType": "AREA_2",
          "area2extraFee": 5000,
        },
      },

      "claimDeliveryInfo": {
        "returnDeliveryCompanyPriorityType": "PRIMARY",
        "returnDeliveryFee": 4000,
        "exchangeDeliveryFee": 8000,
      },
      # "installationFee": False, # 별도 설치비 유무
      # "expectedDeliveryPeriodType": "ETC",
      # "expectedDeliveryPeriodDirectInput": "string",
      # "todayStockQuantity": 0,
      # "customProductAfterOrderYn": True,
      # "hopeDeliveryGroupId": 0
    }

# %%
post_body = { 
    
  ########################################
  ### 1. 원상품 정보 구조체             ###
  ########################################
  "originProduct": {
      
    # 상품 상태: 상품 등록시엔 SALE만 입력 가능
    "statusType": "SALE",       

    # 새상품(NEW) / 중고상품 (OLD) 
    "saleType": "NEW",           
    
    # 카테고리 ID
    "leafCategoryId": leafCategoryId,  
    
    # 상품명
    "name": name,            
    
    # 상품 상세설명
    "detailContent": detailContent,   

    # 상품 이미지로 대표 이미지(1000x1000픽셀 권장)와 최대 9개의 추가 이미지 목록을 제공할 수 있습니다. 
    # 대표 이미지는 필수이고 추가 이미지는 선택 사항입니다. 
    # 이미지 URL은 반드시 상품 이미지 다건 등록 API로 이미지를 업로드하고 반환받은 URL 값을 입력해야 합니다.
    "images": {
      "representativeImage": { "url": representativeImageURL },  # 대표이미지
      "optionalImages": optionalImagesURLs      # 추가이미지
    },

    # 판매 시작일, 판매 마감일
      # 'yyyy-MM-dd'T'HH:mm[:ss][.SSS]XXX' 형식으로 입력
    "saleStartDate": saleStartDate,  # 현재부터 3분 후      
    "saleEndDate": saleEndDate,       # 2099-01-13T01:30:56Z,    

    # 판매 가격
    "salePrice": salePrice,

    # 재고량                              
    "stockQuantity": 0,                           
    
    # 배달정보 : 이건 유형을 만들어서 넣는 방식으로 하자. -> 언제 다 넣냐..
    "deliveryInfo": deliveryInfo,

    ## Array of objects (물류사 정보): 풀필먼트 이용 상품은 필수 -> 네이버 물류 연합군의 풀필먼트 서비스를 이용하고 있는 경우 상품에 물류사/물류센터 정보를 입력합니다.
    # "productLogistics": [
    #   { "logisticsCompanyId": "string"}            # string (물류사 ID)
    # ],

    # 원상품 상세 속성
    "detailAttribute": {
      # 네이버쇼핑 검색어 정보
      # "naverShoppingSearchInfo": {
      #   "modelId": catalog_Id,
      #   "modelName": catalog_Name,
      #   "manufacturerName": manufacturerName,
      #   "brandId": brandId,
      #   "brandName": brandName
      # },
      # A/S 정보
      "afterServiceInfo": {
        "afterServiceTelephoneNumber": afterServiceTelephoneNumber,
        "afterServiceGuideContent": afterServiceGuideContent
      },
      # 구매 수량 정보
      # "purchaseQuantityInfo": purchaseQuantityInfo,
      # 원산지 정보
      "originAreaInfo": originAreaInfo_JAPAN,
      
      # # 판매자 코드 정보
      # "sellerCodeInfo": {
      #   "sellerManagementCode": "string",
      #   "sellerBarcode": "string",
      #   "sellerCustomCode1": "string",
      #   "sellerCustomCode2": "string"
      # },

      # 옵션 정보. [단독형 옵션, 조합형 옵션, 직접 입력형] 옵션 중 최소 한 개는 입력해야 함.
      # 즉, optionSimple, optionCustom, optionCombinations 중 하나는 입력해야 함.
      # 단독형 옵션과 조합형 옵션은 함께 사용할 수 없다.
      "optionInfo": optionInfo,


      # 추가 상품 정보: 등록된 기본 상품과 함께 구성하면 좋은 상품으로 구성 : 
      # 여긴 디폴트로 생략하고, 네이버 스토에서 수동 설정하는걸로 하자.
      # "supplementProductInfo": {
      #   "sortType": "CREATE",
      #   "supplementProducts": [
      #     {
      #       "id": 0,
      #       "groupName": "string",
      #       "name": "string",
      #       "price": 0,
      #       "stockQuantity": 0,
      #       "sellerManagementCode": "string",
      #       "usable": true
      #     }
      #   ]
      # },

      #리뷰 노출 설정 정보 
      "purchaseReviewInfo": {
        "purchaseReviewExposure": True,
        # "reviewUnExposeReason": "string"  # 리뷰 미노출 사유. 리뷰 노출 여부가 false일 경우 리뷰 미노출 사유를 입력해야 합니다.
      },

      ## ISBN 정보
      # "isbnInfo": {
      #   "isbn13": "string",
      #   "issn": "string",
      #   "independentPublicationYn": True
      # },
      ## 도서 항목 부가 정보
      # "bookInfo": {
      #   "publishDay": "string",
      #   "publisher": { "code": "string", "text": "string" },
      #   "authors": [{ "code": "string", "text": "string" }],
      #   "illustrators": [{ "code": "string", "text": "string" }],
      #   "translators": [{ "code": "string", "text": "string" }]
      # },

      # # (이벤트 문구(홍보 문구 대체))
      # "eventPhraseCont": eventPhraseCont,
      # 제조일자 : 인증 유형이 방송통신기자재 적합인증/적합등록/잠정인증인 경우 필수. 'yyyy-MM-dd' 형식 입력.
      "manufactureDate": manufactureDate, # "2024-01-13",
      # # 출시일자 : 수정/삭제 불가능. 브랜드스토어 한정
      # "releaseDate": releaseDate,
      # 유효일자: 
      "validDate": validDate,
      # 부가가치세 타입 : 디폴트는 과세상품 -> TAX(과세 상품), DUTYFREE(면세 상품), SMALL(영세 상품)
      "taxType": "TAX",   # taxType,
      
      # 인증정보 목록:  '어린이제품 인증 대상' 카테고리 상품인 경우 필수
      "productCertificationInfos": productCertificationInfos,
      # 인증대상 제외여부 검토
      "certificationTargetExcludeContent": {
    "childCertifiedProductExclusionYn": True,                     # 어린이제품 인증 대상 제외 여부: 필수. 미입력 시 false로 저장됩니다
    "kcExemptionType": "OVERSEAS",                                # KC 면제 대상 타입  (구매대행/병행이면 필수 입력): SAFE_CRITERION(안전기준준수대상(안전기준준수대상 예외 카테고리가 아닌 경우에도 설정 가능, 식품 카테고리 외)), OVERSEAS(구매대행), PARALLEL_IMPORT(병행수입)
    "kcCertifiedProductExclusionYn": "KC_EXEMPTION_OBJECT",       # TRUE(KC 인증 대상 아님), FALSE(KC 인증 대상), KC_EXEMPTION_OBJECT(안전기준준수, 구매대행, 병행수입인 경우 필수 입력)
    "greenCertifiedProductExclusionYn": True                      # 친환경 인증 대상 제외 여부
  },

      # # 판매자 특이사항
      # "sellerCommentContent": "없음",
      # # 판매자 특이사항 사용 여부
      # "sellerCommentUsable": False,

      # 미성년자 구매 가능 여부
      "minorPurchasable": minorPurchasable,

      # # E 쿠폰
      # "ecoupon": {
      #   "periodType": "FIXED",
      #   "validStartDate": "2024-01-13",
      #   "validEndDate": "2024-01-13",
      #   "periodDays": 0,
      #   "publicInformationContents": "string",
      #   "contactInformationContents": "string",
      #   "usePlaceType": "PLACE",
      #   "usePlaceContents": "string",
      #   "restrictCart": True,
      #   "siteName": "string"
      # },

      # 상품정보제공고시
      "productInfoProvidedNotice": productInfoProvidedNotice,

  
      # 상품속성 목록
      "productAttributes": [
        # {
        #   "attributeSeq": 0,
        #   "attributeValueSeq": 0,
        #   "attributeRealValue": "string",
        #   "attributeRealValueUnitCode": "string"
        # }
      ],
      # 문화비 소득공제 여부 : 예외 카테고리 중 도서_일반, 도서_해외, 도서_중고, 도서_E북, 도서_오디오북, 문화비_소득공제에 해당하는 경우 입력할 수 있습니다. 미입력 시 false로 저장됩니다.
      # "cultureCostIncomeDeductionYn": cultureCostIncomeDeductionYn,
      # 맞춤 제작 상품 여부
      "customProductYn": customProductYn,
      # 자체 제작 상품 여부
      "itselfProductionProductYn": itselfProductionProductYn,
      # 브랜드 인증 여부
      # "brandCertificationYn": brandCertificationYn,
      # (SEO(Search engine optimization) 정보)
      "seoInfo": seoInfo
    },
 
    # 상품 고객 헤택 정보
    "customerBenefit": {
      # 즉시 할인 정책
      "immediateDiscountPolicy": {
        # PC 할인 방법
        "discountMethod": {
          "value": discount_value,
          "unitType": discount_unitType,
          "startDate": Discount_StartDate,
          "endDate": Discount_EndDate      # '2099-01-13T01:30:56Z'
        },

        # 모바일 할인방법
        "mobileDiscountMethod": {
          "value": discount_value,
          "unitType": discount_unitType,
          "startDate": Discount_StartDate,
          "endDate": Discount_EndDate      # '2099-01-13T01:30:56Z'
        }
      },
      # "purchasePointPolicy": {
      #   "value": 0,
      #   "unitType": "PERCENT",
      #   "startDate": "2024-01-13",
      #   "endDate": "2024-01-13"
      # },
      # "reviewPointPolicy": {
      #   "textReviewPoint": 0,
      #   "photoVideoReviewPoint": 0,
      #   "afterUseTextReviewPoint": 0,
      #   "afterUsePhotoVideoReviewPoint": 0,
      #   "storeMemberReviewPoint": 0,
      #   "startDate": "2024-01-13",
      #   "endDate": "2024-01-13"
      # },
      # "freeInterestPolicy": {
      #   "value": 0,
      #   "startDate": "2024-01-13",
      #   "endDate": "2024-01-13"
      # },
      # "giftPolicy": { "presentContent": "string" },
      # "multiPurchaseDiscountPolicy": {
      #   "discountMethod": {
      #     "value": 1,
      #     "unitType": "PERCENT",
      #     "startDate": "2024-01-13",
      #     "endDate": "2024-01-13"
      #   },
      #   "orderValue": 0,
      #   "orderValueUnitType": "PERCENT"
      # },
      # "reservedDiscountPolicy": {
      #   "discountMethod": {
      #     "value": 1,
      #     "unitType": "PERCENT",
      #     "startDate": "2024-01-13T01:30:56Z",
      #     "endDate": "2024-01-13T01:30:56Z"
      #   }
      # }
    }
  },
  
  ########################################
  ### 2 스마트스토어 채널상품 정보 구조체 ###
  ########################################
  "smartstoreChannelProduct": {
    # "channelProductName": "string",
    # "bbsSeq": 0,
    # "storeKeepExclusiveProduct": True,
    "naverShoppingRegistration": False,      # 네이버 쇼핑 광고주가 아닌 경우에는 false로 저장됩니다.
    "channelProductDisplayStatusType": "ON"  # WAIT(전시 대기), ON(전시 중), SUSPENSION(전시 중지)
  },
  # "windowChannelProduct": {
  #   # "channelProductName": "string",
  #   # "bbsSeq": 0,
  #   # "storeKeepExclusiveProduct": True,
  #   "naverShoppingRegistration": False,
  #   # "channelNo": 0,
  #   "best": True
  # }
}

# %%
# 필수가 아니면 이렇게 따로 넣자.
post_body['originProduct']['detailAttribute']['naverShoppingSearchInfo'] = naverShoppingSearchInfo

# %%
Discount_EndDate+'+09:00'
# Out:
# '2099-01-13T01:59:00Z+09:00'

# %%
type(post_body)
# Out:
# dict

# %%
with open('postbody.json', 'w') as f:
    json.dump(json.dumps(post_body), f)

# %%
len(json.load(open('postbody.json', 'r')))
# Out:
# 13023

# %%
import http.client

conn = http.client.HTTPSConnection("api.commerce.naver.com")

payload = json.load(open('postbody.json', 'r'))
headers = {
    'Authorization': f"Bearer {access_token}",
    'content-type': "application/json"
    }

conn.request("POST", "/external/v2/products", payload, headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"originProductNo":9895008206,"smartstoreChannelProductNo":9942583717}

# %%
payload
# Out:
# '{"originProduct": {"statusType": "SALE", "saleType": "NEW", "leafCategoryId": "50003860", "name": "\\uc544\\uc2dd\\uc2a4 \\uc548\\uc804\\ud654 \\uc708\\uc7a1 \\ubcf4\\uc544 \\uc548\\uc804 \\uc791\\uc5c5\\ud654 CP306 1273A029", "detailContent": "\\uc544\\uc2dd\\uc2a4 \\uc548\\uc804\\ud654 \\uc708\\uc7a1 \\ubcf4\\uc544 \\uc548\\uc804 \\uc791\\uc5c5\\ud654 CP306 1273A029 \\uc785\\ub2c8\\ub2e4.", "images": {"representativeImage": {"url": "http://shop1.phinf.naver.net/20240122_142/1705929358409wTYVQ_JPEG/5455576275694206_1220525852.jpg"}, "optionalImages": [{"url": "http://shop1.phinf.naver.net/20240122_136/1705923655839s4Geh_JPEG/31112929740018466_1265233498.jpg"}, {"url": "http://shop1.phinf.naver.net/20240122_150/17059293589071DlnP_JPEG/56280742860303359_1054031388.jpg"}, {"url": "http://shop1.phinf.naver.net/20240122_112/1705929358680v11dv_JPEG/56541127863940465_1501463376.jpg"}]}, "saleStartDate": "2024-02-12T13:58:02Z", "saleEndDate": "2099-01-13T01:30:56Z", "salePrice": 150000, "stockQuantity": 0, "deliveryInfo": {"deliveryType": "DELIVERY", "deliveryAttributeType": "NORMAL", "deliveryCompany": "EPOST", "deliveryBundleGroupUsable": true, "deliveryFee": {"deliveryFeeType": "PAID", "baseFee": 4000, "deliveryFeePayType": "PREPAID", "deliveryFeeByArea": {"deliveryAreaType": "AREA_2", "area2extraFee": 5000}}, "claimDeliveryInfo": {"returnDeliveryCompanyPriorityType": "PRIMARY", "returnDeliveryFee": 4000, "exchangeDeliveryFee": 8000}}, "detailAttribute": {"naverShoppingSearchInfo": {"modelId": "42538144516", "modelName": "\\uc544\\uc2dd\\uc2a4 \\uc548\\uc804\\ud654 \\uc708\\uc7a1 \\ubcf4\\uc544 \\uc548\\uc804 \\uc791\\uc5c5\\ud654 CP306 1273A029", "manufacturerName": "\\uc544\\uc2dd\\uc2a4", "brandId": 654, "brandName": "\\uc544\\uc2dd\\uc2a4"}, "afterServiceInfo": {"afterServiceTelephoneNumber": "010-2936-1595", "afterServiceGuideContent": "\\uc0c1\\ud488 \\uc624\\ubc30\\uc1a1 \\ubc0f \\ud30c\\uc1a1\\uc2dc A/S \\ub3c4\\uc640\\ub4dc\\ub9ac\\uaca0\\uc2b5\\ub2c8\\ub2e4"}, "originAreaInfo": {"originAreaCode": "0200036", "importer": "japan", "content": "string", "plural": true}, "optionInfo": {"simpleOptionSortType": "CREATE", "optionSimple": [], "optionCombinationSortType": "CREATE", "standardOptionGroups": [{"groupName": "\\uc0c9\\uc0c1", "standardOptionAttributes": [{"attributeId": 10014203, "attributeValueId": 10031739, "attributeValueName": "\\ub808\\ub4dc", "imageUrls": "http://shop1.phinf.naver.net/20240122_142/1705929358409wTYVQ_JPEG/5455576275694206_1220525852.jpg"}, {"attributeId": 10014203, "attributeValueId": 10031742, "attributeValueName": "\\uc610\\ub85c\\uc6b0", "imageUrls": "http://shop1.phinf.naver.net/20240122_136/1705923655839s4Geh_JPEG/31112929740018466_1265233498.jpg"}, {"attributeId": 10014203, "attributeValueId": 10531869, "attributeValueName": "\\ud654\\uc774\\ud2b8", "imageUrls": "http://shop1.phinf.naver.net/20240122_150/17059293589071DlnP_JPEG/56280742860303359_1054031388.jpg"}, {"attributeId": 10014203, "attributeValueId": 10031727, "attributeValueName": "\\ube14\\ub799", "imageUrls": "http://shop1.phinf.naver.net/20240122_112/1705929358680v11dv_JPEG/56541127863940465_1501463376.jpg"}]}, {"groupName": "\\uc0ac\\uc774\\uc988(\\ud55c\\uad6d)", "standardOptionAttributes": [{"attributeId": 10014204, "attributeValueId": 10696136, "attributeValueName": "225"}, {"attributeId": 10014204, "attributeValueId": 10696137, "attributeValueName": "230"}, {"attributeId": 10014204, "attributeValueId": 10696138, "attributeValueName": "235"}, {"attributeId": 10014204, "attributeValueId": 10696139, "attributeValueName": "240"}, {"attributeId": 10014204, "attributeValueId": 10696140, "attributeValueName": "245"}, {"attributeId": 10014204, "attributeValueId": 10696141, "attributeValueName": "250"}, {"attributeId": 10014204, "attributeValueId": 10696142, "attributeValueName": "255"}, {"attributeId": 10014204, "attributeValueId": 10696143, "attributeValueName": "260"}, {"attributeId": 10014204, "attributeValueId": 10696144, "attri ...

# %%
json.dumps(post_body)
# Out:
# '{"originProduct": {"statusType": "SALE", "saleType": "NEW", "leafCategoryId": "50003860", "name": "\\uc544\\uc2dd\\uc2a4 \\uc548\\uc804\\ud654 \\uc708\\uc7a1 \\ubcf4\\uc544 \\uc548\\uc804 \\uc791\\uc5c5\\ud654 CP306 1273A029", "detailContent": "\\uc544\\uc2dd\\uc2a4 \\uc548\\uc804\\ud654 \\uc708\\uc7a1 \\ubcf4\\uc544 \\uc548\\uc804 \\uc791\\uc5c5\\ud654 CP306 1273A029 \\uc785\\ub2c8\\ub2e4.", "images": {"representativeImage": {"url": "http://shop1.phinf.naver.net/20240122_136/1705923655839s4Geh_JPEG/31112929740018466_1265233498.jpg"}, "optionalImages": [{"url": "http://shop1.phinf.naver.net/20240122_136/1705923655839s4Geh_JPEG/31112929740018466_1265233498.jpg"}, {"url": "http://shop1.phinf.naver.net/20240122_142/1705929358409wTYVQ_JPEG/5455576275694206_1220525852.jpg"}, {"url": "http://shop1.phinf.naver.net/20240122_112/1705929358680v11dv_JPEG/56541127863940465_1501463376.jpg"}, {"url": "http://shop1.phinf.naver.net/20240122_150/17059293589071DlnP_JPEG/56280742860303359_1054031388.jpg"}]}, "saleStartDate": ["2024-01-26T10:40:03Z"], "saleEndDate": "2099-01-13T01:30:56Z", "salePrice": 150000, "stockQuantity": 0, "deliveryInfo": {"deliveryType": "DELIVERY", "deliveryAttributeType": "NORMAL", "deliveryCompany": "string", "deliveryBundleGroupUsable": true, "deliveryBundleGroupId": 0, "quickServiceAreas": ["SEOUL"], "visitAddressId": 0, "deliveryFee": {"deliveryFeeType": "FREE", "baseFee": 0, "freeConditionalAmount": 0, "repeatQuantity": 0, "secondBaseQuantity": 0, "secondExtraFee": 0, "thirdBaseQuantity": 0, "thirdExtraFee": 0, "deliveryFeePayType": "COLLECT", "deliveryFeeByArea": {"deliveryAreaType": "AREA_2", "area2extraFee": 0, "area3extraFee": 0}, "differentialFeeByArea": "string"}, "claimDeliveryInfo": {"returnDeliveryCompanyPriorityType": "PRIMARY", "returnDeliveryFee": 0, "exchangeDeliveryFee": 0, "shippingAddressId": 0, "returnAddressId": 0, "freeReturnInsuranceYn": true}, "installationFee": true, "expectedDeliveryPeriodType": "ETC", "expectedDeliveryPeriodDirectInput": "string", "todayStockQuantity": 0, "customProductAfterOrderYn": true, "hopeDeliveryGroupId": 0}, "detailAttribute": {"naverShoppingSearchInfo": {"modelId": "42538144516", "modelName": "\\uc544\\uc2dd\\uc2a4 \\uc548\\uc804\\ud654 \\uc708\\uc7a1 \\ubcf4\\uc544 \\uc548\\uc804 \\uc791\\uc5c5\\ud654 CP306 1273A029", "manufacturerName": "\\uc544\\uc2dd\\uc2a4", "brandId": 654, "brandName": "\\uc544\\uc2dd\\uc2a4"}, "afterServiceInfo": {"afterServiceTelephoneNumber": "010-2936-1595", "afterServiceGuideContent": "\\uc0c1\\ud488 \\uc624\\ubc30\\uc1a1 \\ubc0f \\ud30c\\uc1a1\\uc2dc A/S \\ub3c4\\uc640\\ub4dc\\ub9ac\\uaca0\\uc2b5\\ub2c8\\ub2e4"}, "purchaseQuantityInfo": {"minPurchaseQuantity": 1, "maxPurchaseQuantityPerId": 100, "maxPurchaseQuantityPerOrder": 100}, "originAreaInfo": {"originAreaCode": "0200036", "importer": "japan", "content": "string", "plural": true}, "optionInfo": {"simpleOptionSortType": "CREATE", "optionSimple": [], "optionCombinationSortType": "CREATE", "standardOptionGroups": [{"groupName": "\\uc0c9\\uc0c1", "standardOptionAttributes": [{"attributeId": 1, "attributeValueId": 1, "attributeValueName": "black", "imageUrls": ["http://shop1.phinf.naver.net/20240122_136/1705923655839s4Geh_JPEG/31112929740018466_1265233498.jpg"]}, {"attributeId": 2, "attributeValueId": 2, "attributeValueName": "red", "imageUrls": ["http://shop1.phinf.naver.net/20240122_142/1705929358409wTYVQ_JPEG/5455576275694206_1220525852.jpg"]}, {"attributeId": 3, "attributeValueId": 3, "attributeValueName": "white", "imageUrls": ["http://shop1.phinf.naver.net/20240122_112/1705929358680v11dv_JPEG/56541127863940465_1501463376.jpg"]}, {"attributeId": 4, "attributeValueId": 4, "attributeValueName": "yellow", "imageUrls": ["http://shop1.phinf.naver.net/20240122_150/17059293589071DlnP_JPEG/56280742860303359_1054031388.jpg"]}]}, {"groupName": "\\uc0ac\\uc774\\uc988", "standardOptionAttributes": [{"attributeId": 255, "attributeValueId": 1, "attributeValueName": "255"}, {"attributeId": 260,  ...

# %%
upload_url = 'https://api.commerce.naver.com/external/v2/products'
headers = {
    'Authorization': f"Bearer {access_token}",
    'content-type': "application/json"
    }
response =requests.post(upload_url, json.dumps(post_body) ,headers=headers )

# %%
response.text
# Out:
# '{"code":"BAD_REQUEST","message":"잘못된 형식으로 JSON 데이터를 입력하셨습니다. - Cannot deserialize value of type `com.naver.ncp.sell.product.business.entity.product.enumeration.TaxType` from Array value (token `JsonToken.START_ARRAY`) [line: 1 column: 4,431]","timestamp":"2024-01-26T20:32:10.410+09:00"}'

# %% [markdown]
# 개발 방향  : 아마존/라쿠텐 링크로 연결시킬수 있는 정보들은 생략하고 / 나머지 직접 써야하는 부분이나 이미지만 입력하면 바로 스마트 스토어에 올릴 수 있게 하는 프로그램으로 !

# %%
a.replace('\n','')
# Out:
# '"books": {    "returnCostReason": "string",    "noRefundReason": "string",    "qualityAssuranceStandard": "string",    "compensationProcedure": "string",    "troubleShootingContents": "string",    "title": "string",    "author": "string",    "publisher": "string",    "size": "string",    "pages": "string",    "components": "string",    "publishDate": "2024-01-13",    "publishDateText": "string",    "description": "string"},'

# %% [markdown]
# # 상품정보제공고시 정보

# %%
from ItemInfo_notification import Item_Info_Nofication

# %%
list(Item_Info_Nofication.keys())
# Out:
# ['wear',
#  'shoes',
#  'bag',
#  'fashionItems',
#  'sleepingGear',
#  'furniture',
#  'imageAppliances',
#  'homeAppliances',
#  'seasonAppliances',
#  'officeAppliances',
#  'opticsAppliances',
#  'microElectronics',
#  'navigation',
#  'carArticles',
#  'medicalAppliances',
#  'kitchenUtensils',
#  'cosmetic',
#  'jewellery',
#  'food',
#  'generalFood',
#  'dietFood',
#  'kids',
#  'musicalInstrument',
#  'sportsEquipment',
#  'books',
#  'rentalEtc',
#  'digitalContents',
#  'giftCard',
#  'mobileCoupon',
#  'movieShow',
#  'etcService',
#  'biochemistry',
#  'biocidal',
#  'cellPhone',
#  'etc']

# %%
Item_Info_Nofication
# Out:
# {'wear': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'material',
#   'color',
#   'size',
#   'manufacturer',
#   'caution',
#   'packDate',
#   'packDateText',
#   'warrantyPolicy',
#   'afterServiceDirector'],
#  'shoes': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'material',
#   'color',
#   'size',
#   'height',
#   'manufacturer',
#   'caution',
#   'warrantyPolicy',
#   'afterServiceDirector'],
#  'bag': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'type',
#   'material',
#   'color',
#   'size',
#   'manufacturer',
#   'caution',
#   'warrantyPolicy',
#   'afterServiceDirector'],
#  'fashionItems': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'type',
#   'material',
#   'size',
#   'manufacturer',
#   'caution',
#   'warrantyPolicy',
#   'afterServiceDirector'],
#  'sleepingGear': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'material',
#   'color',
#   'size',
#   'components',
#   'manufacturer',
#   'caution',
#   'warrantyPolicy',
#   'afterServiceDirector'],
#  'furniture': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'itemName',
#   'certificationType',
#   'color',
#   'components',
#   'material',
#   'manufacturer',
#   'importer',
#   'producer',
#   'size',
#   'installedCharge',
#   'warrantyPolicy',
#   'refurb',
#   'afterServiceDirector'],
#  'imageAppliances': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'itemName',
#   'modelName',
#   'certificationType',
#   'ratedVoltage',
#   'powerConsumption',
#   'energyEfficiencyRating',
#   'releaseDate',
#   'releaseDateText',
#   'manufacturer',
#   'size',
#   'additionalCost',
#   'displaySpecification',
#   'warrantyPolicy',
#   'afterServiceDirector'],
#  'homeAppliances': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'itemName',
#   'modelName',
#   'certificationType',
#   'ratedVoltage',
#   'powerConsumption',
#   'energyEfficiencyRating',
#   'releaseDate',
#   'releaseDateText',
#   'manufacturer',
#   'size',
#   'additionalCost',
#   'warrantyPolicy',
#   'afterServiceDirector'],
#  'seasonAppliances': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'itemName',
#   'modelName',
#   'certificationType',
#   'ratedVoltage',
#   'powerConsumption',
#   'energyEfficiencyRating',
#   'releaseDate',
#   'releaseDateText',
#   'manufacturer',
#   'size',
#   'area',
#   'installedCharge',
#   'warrantyPolicy',
#   'afterServiceDirector'],
#  'officeAppliances': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'itemName',
#   'modelName',
#   'certificationType',
#   'ratedVoltage',
#   'powerConsumption',
#   'energyEfficiencyRating',
#   'releaseDate',
#   'releaseDateText',
#   'manufacturer',
#   'size',
#   'weight',
#   'specification',
#   'warrantyPolicy',
#   'afterServiceDirector'],
#  'opticsAppliances': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'itemName',
#   'modelName',
#   'certificationType',
#   'releaseDate',
#   'releaseDateText',
#   'manufacturer',
#   'size',
#   'weight',
#   'specification',
#   'warrantyPolicy',
#   'afterServiceDirector'],
#  'microElectronics': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'itemName',
#   'modelName',
#   'certificationType',
#   'ratedVoltage',
#   'powerConsumption',
#   'releaseDate',
#   'releaseDateText',
#   'manufacturer',
#   'size',
#   'weight',
#   'specification',
#   'warrantyPolicy',
#   'afterServiceDirector'],
#  'navigation': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'itemName',
#   'modelName',
#   'certificationType',
#   'ratedVoltage',
#   'powerConsumption',
#   'releaseDate',
#   'releaseDateText',
#   'manufacturer',
#   'size',
#   'weight',
#   'specification',
#   'updateCost',
#   'freeCostPeriod',
#   'warrantyPolicy',
#   'afterServiceDirector'],
#  'carArticles': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'itemName',
#   'modelName',
#   'releaseDate',
#   'releaseDateText',
#   'certificationType',
#   'caution',
#   'manufacturer',
#   'size',
#   'applyModel',
#   'warrantyPolicy',
#   'roadWorthyCertification',
#   'afterServiceDirector'],
#  'medicalAppliances': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'itemName',
#   'modelName',
#   'licenceNo',
#   'advertisingCertificationType',
#   'ratedVoltage',
#   'powerConsumption',
#   'releaseDate',
#   'releaseDateText',
#   'manufacturer',
#   'purpose',
#   'usage',
#   'caution',
#   'warrantyPolicy',
#   'afterServiceDirector'],
#  'kitchenUtensils': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'itemName',
#   'modelName',
#   'material',
#   'component',
#   'size',
#   'releaseDate',
#   'releaseDateText',
#   'manufacturer',
#   'producer',
#   'importDeclaration',
#   'warrantyPolicy',
#   'afterServiceDirector'],
#  'cosmetic': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'capacity',
#   'specification',
#   'expirationDate',
#   'expirationDateText',
#   'usage',
#   'manufacturer',
#   'producer',
#   'distributor',
#   'customizedDistributor',
#   'mainIngredient',
#   'certificationType',
#   'caution',
#   'warrantyPolicy',
#   'customerServicePhoneNumber'],
#  'jewellery': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'material',
#   'purity',
#   'bandMaterial',
#   'weight',
#   'manufacturer',
#   'producer',
#   'size',
#   'caution',
#   'specification',
#   'provideWarranty',
#   'warrantyPolicy',
#   'afterServiceDirector'],
#  'food': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'foodItem',
#   'weight',
#   'amount',
#   'size',
#   'packDate',
#   'packDateText',
#   'expirationDate',
#   'expirationDateText',
#   'consumptionDate',
#   'consumptionDateText',
#   'producer',
#   'relevantLawContent',
#   'productComposition',
#   'keep',
#   'adCaution',
#   'customerServicePhoneNumber'],
#  'generalFood': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'productName',
#   'foodType',
#   'producer',
#   'location',
#   'packDate',
#   'packDateText',
#   'expirationDate',
#   'expirationDateText',
#   'consumptionDate',
#   'consumptionDateText',
#   'weight',
#   'amount',
#   'ingredients',
#   'nutritionFacts',
#   'geneticallyModified',
#   'consumerSafetyCaution',
#   'importDeclarationCheck',
#   'customerServicePhoneNumber'],
#  'dietFood': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'productName',
#   'producer',
#   'location',
#   'expirationDate',
#   'expirationDateText',
#   'consumptionDate',
#   'consumptionDateText',
#   'storageMethod',
#   'weight',
#   'amount',
#   'ingredients',
#   'nutritionFacts',
#   'specification',
#   'cautionAndSideEffect',
#   'nonMedicinalUsesMessage',
#   'geneticallyModified',
#   'importDeclarationCheck',
#   'consumerSafetyCaution',
#   'customerServicePhoneNumber'],
#  'kids': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'itemName',
#   'modelName',
#   'certificationType',
#   'size',
#   'weight',
#   'color',
#   'material',
#   'recommendedAge',
#   'releaseDate',
#   'releaseDateText',
#   'manufacturer',
#   'caution',
#   'warrantyPolicy',
#   'afterServiceDirector',
#   'numberLimit'],
#  'musicalInstrument': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'itemName',
#   'modelName',
#   'size',
#   'color',
#   'material',
#   'components',
#   'releaseDate',
#   'releaseDateText',
#   'manufacturer',
#   'detailContent',
#   'warrantyPolicy',
#   'afterServiceDirector'],
#  'sportsEquipment': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'itemName',
#   'modelName',
#   'certificationType',
#   'size',
#   'weight',
#   'color',
#   'material',
#   'components',
#   'releaseDate',
#   'releaseDateText',
#   'manufacturer',
#   'detailContent',
#   'warrantyPolicy',
#   'afterServiceDirector'],
#  'books': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'title',
#   'author',
#   'publisher',
#   'size',
#   'pages',
#   'components',
#   'publishDate',
#   'publishDateText',
#   'description'],
#  'rentalEtc': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'itemName',
#   'modelName',
#   'ownershipTransferCondition',
#   'payingForLossOrDamage',
#   'refundPolicyForCancel',
#   'customerServicePhoneNumber'],
#  'digitalContents': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'producer',
#   'termsOfUse',
#   'usePeriod',
#   'medium',
#   'requirement',
#   'cancelationPolicy',
#   'customerServicePhoneNumber'],
#  'giftCard': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'issuer',
#   'periodStartDate',
#   'periodEndDate',
#   'periodDays',
#   'termsOfUse',
#   'useStorePlace',
#   'useStoreAddressId',
#   'useStoreUrl',
#   'refundPolicy',
#   'customerServicePhoneNumber'],
#  'mobileCoupon': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'issuer',
#   'usableCondition',
#   'usableStore',
#   'cancelationPolicy',
#   'customerServicePhoneNumber'],
#  'movieShow': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'sponsor',
#   'actor',
#   'rating',
#   'showTime',
#   'showPlace',
#   'cancelationCondition',
#   'cancelationPolicy',
#   'customerServicePhoneNumber'],
#  'etcService': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'serviceProvider',
#   'certificateDetails',
#   'usableCondition',
#   'cancelationStandard',
#   'cancelationPolicy',
#   'customerServicePhoneNumber'],
#  'biochemistry': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'productName',
#   'dosageForm',
#   'packDate',
#   'packDateText',
#   'expirationDate',
#   'expirationDateText',
#   'weight',
#   'effect',
#   'importer',
#   'producer',
#   'manufacturer',
#   'childProtection',
#   'chemicals',
#   'caution',
#   'safeCriterionNo',
#   'customerServicePhoneNumber'],
#  'biocidal': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'productName',
#   'weight',
#   'effect',
#   'rangeOfUse',
#   'importer',
#   'producer',
#   'manufacturer',
#   'childProtection',
#   'harmfulChemicalSubstance',
#   'maleficence',
#   'caution',
#   'approvalNumber',
#   'customerServicePhoneNumber',
#   'expirationDate',
#   'expirationDateText'],
#  'cellPhone': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'itemName',
#   'modelName',
#   'certificationType',
#   'releaseDate',
#   'releaseDateText',
#   'manufacturer',
#   'importer',
#   'producer',
#   'size',
#   'weight',
#   'telecomType',
#   'joinProcess',
#   'extraBurden',
#   'specification',
#   'warrantyPolicy',
#   'afterServiceDirector'],
#  'etc': ['returnCostReason',
#   'noRefundReason',
#   'qualityAssuranceStandard',
#   'compensationProcedure',
#   'troubleShootingContents',
#   'itemName',
#   'modelName',
#   'certificateDetails',
#   'manufacturer',
#   'afterServiceDirector',
#   'customerServicePhoneNumber']}
